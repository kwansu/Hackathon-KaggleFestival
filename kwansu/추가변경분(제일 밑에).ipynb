# %% [markdown]
# 시각화
#
# 5.2
#
# holy1,2 => 그래프 2개
#
#
# 5.3
#
# 지역마다 장르 => 그래프 3개
#
# 6.1
# 주, 월 장르,  2개 golden week
#
#
#
#
# 요일 장르 이름 holy1,2 month, , golden week => 레스토랑 평소에 비해 얼마나 운영하는지  => 시계열 주기를 가지고 있고 =>
#
# 주//// 달마다 장르별 차이, golden week => (레스토랑 평소에 비해 얼마나 운영수 / 방문자들 평균(골든 vs 다른 평범한 1주)
#
#
# hue => 각월마다 장르 = hue 방문수를 count
#
#
# 가게당 요일별 최대최소평균 => 가게당 특성부여 x
# 장르별 요일 최소최대평균 장르,가게 =>
#
# /아이디당 요일별 최소최대 평균,
#
# 날씨 강수량 => 오고 안오고 / 간격 =>
#
# 평균온도, 최대, 최소 =>
#
#
# 모델
#
# lgm => gridsearch
#
#
#
# ////노쇼 시간/// 유동인구/// hpg => 지역 ///
#
#
#
# month

# %%
import time
import numpy as np
import pandas as pd
import seaborn as sns
#import seaborn.apionly as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn import *
from dateutil.parser import parse
from datetime import date, timedelta
from sklearn.preprocessing import LabelEncoder
import warnings 
warnings.filterwarnings('ignore')

# %%
data_path = 'data/'

air_reserve = pd.read_csv(data_path + 'air_reserve.csv').rename(columns={'air_store_id':'store_id'})
hpg_reserve = pd.read_csv(data_path + 'hpg_reserve.csv').rename(columns={'hpg_store_id':'store_id'})
air_store = pd.read_csv(data_path + 'air_store_info.csv').rename(columns={'air_store_id':'store_id'})
hpg_store = pd.read_csv(data_path + 'hpg_store_info.csv').rename(columns={'hpg_store_id':'store_id'})
air_visit = pd.read_csv(data_path + 'air_visit_data.csv').rename(columns={'air_store_id':'store_id'})
store_id_map = pd.read_csv(data_path + 'store_id_relation.csv').set_index('hpg_store_id',drop=False)
date_info = pd.read_csv(data_path + 'date_info.csv').rename(columns={'calendar_date': 'visit_date'}).drop('day_of_week',axis=1)
submission = pd.read_csv(data_path + 'sample_submission.csv')

# %%
submission['visit_date'] = submission['id'].str[-10:]
submission['store_id'] = submission['id'].str[:-11]
air_reserve['visit_date'] = air_reserve['visit_datetime'].str[:10]
air_reserve['reserve_date'] = air_reserve['reserve_datetime'].str[:10]
air_reserve['dow'] = pd.to_datetime(air_reserve['visit_date']).dt.dayofweek
hpg_reserve['visit_date'] = hpg_reserve['visit_datetime'].str[:10]
hpg_reserve['reserve_date'] = hpg_reserve['reserve_datetime'].str[:10]
hpg_reserve['dow'] = pd.to_datetime(hpg_reserve['visit_date']).dt.dayofweek

# %%
air_visit['id'] = air_visit['store_id'] + '_' + air_visit['visit_date']
hpg_reserve['store_id'] = hpg_reserve['store_id'].map(store_id_map['air_store_id']).fillna(hpg_reserve['store_id'])
hpg_store['store_id'] = hpg_store['store_id'].map(store_id_map['air_store_id']).fillna(hpg_store['store_id'])
hpg_store.rename(columns={'hpg_genre_name':'air_genre_name','hpg_area_name':'air_area_name'},inplace=True)

# %% [markdown]
# ### 1. Visitors에 대한 관찰

# %% [markdown]
# ### a. 날짜별 방문자수

# %%
fig = plt.figure(figsize = (10, 4))
air_visit.groupby(['visit_date'])['visitors'].sum().plot()
# Out:
# <AxesSubplot:xlabel='visit_date'>

# %% [markdown]
# - 주기적인 패턴이보인다 => 주, 월별로 분석해볼 생각을 할 수 있다.
# - 16년 7월쯤 급격히 증가한다,

# %%
sns.distplot(air_visit['visitors'])
# Out:
# <AxesSubplot:xlabel='visitors', ylabel='Density'>

# %%
sns.distplot(air_visit['log_visitors'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\tf_opencv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'log_visitors'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-3d48a82d84e0> in <module>
# ----> 1 sns.distplot(air_visit['log_visitors'])
#
# ~\anaconda3\envs\tf_opencv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\envs\tf_opencv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'log_visitors'

# %% [markdown]
# - 각 날짜별 가게에 방문자 수들간에 심하게 치우쳐짐을 확인가능하다
# - log를 사용하여 정규화를 해야됨이 보인다.

# %%
from numpy import median
f, ax = plt.subplots(1, 2, figsize = (10, 4))
air_visit['dow'] = pd.to_datetime(air_visit['visit_date']).dt.dayofweek
air_visit['month'] = pd.to_datetime(air_visit['visit_date']).dt.month
sns.barplot('dow','visitors',data = air_visit, estimator=median, ax = ax[0])
ax[0].set_xlabel('week')
ax[0].set_ylabel('median_visitor')
ax[0].set_xticklabels(['Mon','Tues',"Wed","Thur","Fri","Sat",'Sun'], rotation='vertical', fontsize=10)
sns.barplot('month','visitors',data = air_visit, ax = ax[1])
ax[1].set_ylabel('median_visitor')
# Out:
# Text(0, 0.5, 'median_visitor')

# %%
f, ax = plt.subplots(1, 2, figsize = (10, 4))
air_visit['dow'] = pd.to_datetime(air_visit['visit_date']).dt.dayofweek
air_visit['month'] = pd.to_datetime(air_visit['visit_date']).dt.month
sns.barplot('dow','visitors',data = air_visit, ax = ax[0])
ax[0].set_xlabel('week')
ax[0].set_ylabel('mean_visitor')
ax[0].set_xticklabels(['Mon','Tues',"Wed","Thur","Fri","Sat",'Sun'], rotation='vertical', fontsize=10)
sns.barplot('month','visitors',data = air_visit, estimator=median, ax = ax[1])
ax[1].set_ylabel('mean_visitor')
# Out:
# Text(0, 0.5, 'mean_visitor')

# %% [markdown]
# - mean이나 median이나 별반 다른게 없다
# - 각 요일별로 방문자 수들의 특성이 보인다

# %%
air_store['air_area_name0'] = air_store['air_area_name'].apply(lambda x: x.split(' ')[0])

# %%
lbl = LabelEncoder()
air_store['air_genre_name0'] = air_store['air_genre_name'].copy()
air_store['air_genre_name'] = lbl.fit_transform(air_store['air_genre_name'])
air_store['air_area_name0'] = lbl.fit_transform(air_store['air_area_name0'])
air_store['genre_count_per_area'] = air_store.groupby(['air_genre_name','air_area_name'])['store_id'].transform('count')
date_info['holiday_flg2'] = pd.to_datetime(date_info['visit_date']).dt.dayofweek
date_info['holiday_flg2'] = ((date_info['holiday_flg2']>4) | (date_info['holiday_flg']==1)).astype(int)

#골든 위크
date_info['golden_week'] = (((date_info['visit_date'].str[5:7] == '04') & (date_info['visit_date'].str[8:10].isin(['29','30']))) |\
                            ((date_info['visit_date'].str[5:7]== '05') & (date_info['visit_date'].str[8:10].isin(['01','02', '03', '04', '05'])))|
                           ((date_info['visit_date'].str[0:5]== '2017') & (date_info['visit_date'].str[5:7]== '05') & (date_info['visit_date'].str[8:10].isin(['06','07'])))).astype(int)
                                                                                                                                                              

data = pd.concat([air_visit, submission]).copy()
data['dow'] = pd.to_datetime(data['visit_date']).dt.dayofweek
data['visitors'] = np.log1p(data['visitors'])
data = data.merge(air_store,on='store_id',how='left')
data = data.merge(date_info[['visit_date','holiday_flg','holiday_flg2','golden_week']], on=['visit_date'],how='left')

# %% [markdown]
# ## 장르와 요일, 월간의 관계

# %%
data['month'] = pd.to_datetime(data['visit_date']).dt.month

# %%
train_size = len(air_visit)
train = data[:train_size]
test = data[train_size:]

# %%
f, ax = plt.subplots(1, 2, figsize = (14, 4))
sns.barplot(x="dow", y="visitors", data=train, ax = ax[0])
ax[0].set_xticklabels(['Mon','Tues',"Wed","Thur","Fri","Sat",'Sun'], rotation='vertical', fontsize=10)
ax[0].set_xlabel('week')
ax[0].set_ylabel('log_visitor_mean')
sns.barplot(x="month", y="visitors", data=train, ax = ax[1])
ax[1].set_ylabel('log_visitor_mean')
plt.show()

# %% [markdown]
# - 방문자 수에 log를 씌운값도 로그를 씌우지 않았을때와 비슷한 패턴을 보인다

# %%
genre_dict = {}
for index, genre_name in enumerate(train['air_genre_name0'].unique()):
    genre_dict[genre_name] = train['air_genre_name'].unique()[index]

# %%
df_genre_dow = train.groupby(['air_genre_name', 'dow'])['visitors'].mean().reset_index()
df_genre_month = train.groupby(['air_genre_name', 'month'])['visitors'].mean().reset_index()

# %%
f, ax = plt.subplots(4, 4, figsize = (20, 12))
for i, key in enumerate(genre_dict.keys()):
    j = i % 4
    k = int(i / 4)
    sns.barplot(x="dow", y="visitors", data = df_genre_dow[df_genre_dow['air_genre_name'] == i], ax = ax[k][j])
    ax[k][j].set_title(key)
    ax[k][j].set_xticklabels(['Mon','Tues',"Wed","Thur","Fri","Sat",'Sun'], rotation='vertical', fontsize=10)
    ax[k][j].set_xlabel('week')
    ax[k][j].set_ylabel('log_visitor_mean')
    ax[k][j].set(ylim = (0, 4))
plt.tight_layout()
plt.show()

# %%
f, ax = plt.subplots(4, 4, figsize = (20, 12))
for i, key in enumerate(genre_dict.keys()):
    j = i % 4
    k = int(i / 4)
    sns.barplot(x="month", y="visitors", data = df_genre_month[df_genre_month['air_genre_name'] == i], ax = ax[k][j])
    ax[k][j].set_title(key)
    #ax[k][j].set_xticklabels(['Mon','Tues',"Wed","Thur","Fri","Sat",'Sun'], rotation='vertical', fontsize=10)
    ax[k][j].set_xlabel('month')
    ax[k][j].set_ylabel('log_visitor_mean')
    ax[k][j].set(ylim = (0, 4))
plt.tight_layout()
plt.show()

# %% [markdown]
# 장르별 주/월마다 다른 패턴을 보이는 것을 확인할 수 있다 => 하나의 feature가 될 수 있음

# %% [markdown]
# ## Golden Week

# %%
train[train['golden_week'] == 1]['store_id'].nunique()
# Out:
# 306

# %%
train[train['golden_week'] == 0]['store_id'].nunique()
# Out:
# 829

# %% [markdown]
# Golden Week일 때 실제로 가게들이 많이 닫는다는 것을 확인할 수 있음

# %%
f, ax = plt.subplots(1, 2, figsize = (14, 4))
sns.barplot(x="dow", y="visitors", data=train[train['golden_week'] == 1], ax = ax[0])
ax[0].set_xticklabels(['Mon','Tues',"Wed","Thur","Fri","Sat",'Sun'], rotation='vertical', fontsize=10)
ax[0].set_xlabel('week')
ax[0].set_ylabel('log_visitor_mean')
ax[0].set_title('Golden Week')
ax[0].set(ylim = (0, 3.5))
sns.barplot(x="dow", y="visitors", data=train[train['golden_week'] == 0], ax = ax[1])
ax[1].set_xticklabels(['Mon','Tues',"Wed","Thur","Fri","Sat",'Sun'], rotation='vertical', fontsize=10)
ax[1].set_ylabel('log_visitor_mean')
ax[1].set_title('Normal Week')
ax[1].set(ylim = (0, 3.5))
plt.show()

# %%
train[(train['golden_week'] == 1) & (train['holiday_flg'] == 1)]['dow'].unique()
# Out:
# array([4, 1, 2, 3], dtype=int64)

# %% [markdown]
# - 화수목금이 골든 위크이자 공휴일이였음
# - 월요일도 그에따라 영향받음을 알 수 있음
# - 골든 위크가 중요한 변수로 작용할 수 있음을 보여준다.

# %%
f, ax = plt.subplots(4, 4,  figsize = (20, 12))
for i, key in enumerate(genre_dict.keys()):
    k = int(i / 4)
    j = i % 4
    if not train[(train['golden_week'] == 1) & (train['air_genre_name'] == i)].empty:
        sns.barplot(x="dow", y="visitors", data = train[(train['golden_week'] == 1) & (train['air_genre_name'] == i)], ax = ax[k][j])
    ax[k][j].set_title(key)
    #ax[k][j].set_xticklabels(['Mon','Tues',"Wed","Thur","Fri","Sat",'Sun'], rotation='vertical', fontsize=10)
    ax[k][j].set_xlabel('week')
    ax[k][j].set_ylabel('log_visitor_mean')
    ax[k][j].set(ylim = (0, 4))

plt.tight_layout()
plt.show()

# %%
f, ax = plt.subplots(4, 4,  figsize = (20, 12))
for i, key in enumerate(genre_dict.keys()):
    k = int(i / 4)
    j = i % 4
    if not train[(train['golden_week'] == 0) & (train['air_genre_name'] == i)].empty:
        sns.barplot(x="dow", y="visitors", data = train[(train['golden_week'] == 0) & (train['air_genre_name'] == i)], ax = ax[k][j])
    ax[k][j].set_title(key)
    #ax[k][j].set_xticklabels(['Mon','Tues',"Wed","Thur","Fri","Sat",'Sun'], rotation='vertical', fontsize=10)
    ax[k][j].set_xlabel('week')
    ax[k][j].set_ylabel('log_visitor_mean')
    ax[k][j].set(ylim = (0, 4))

plt.tight_layout()
plt.show()

# %% [markdown]
# 장르별로 봐도 골든위크일때랑 아닐때랑 다른 패턴을 보이는 곳도 있음

# %% [markdown]
# ## 날씨데이터 이용

# %%
data_with_weather = pd.read_csv("data/data_with_weather.csv")

# %%
data_with_weather.head()
# Out:
#                store_id  visit_date  visitors  \
# 0  air_ba937bf13d40fb24  2016-01-13  3.258097
# 1  air_ba937bf13d40fb24  2016-01-14  3.496508
# 2  air_ba937bf13d40fb24  2016-01-15  3.401197
# 3  air_ba937bf13d40fb24  2016-01-16  3.135494
# 4  air_ba937bf13d40fb24  2016-01-18  1.945910
#
#                                 id  dow  air_genre_name  \
# 0  air_ba937bf13d40fb24_2016-01-13    2               4
# 1  air_ba937bf13d40fb24_2016-01-14    3               4
# 2  air_ba937bf13d40fb24_2016-01-15    4               4
# 3  air_ba937bf13d40fb24_2016-01-16    5               4
# 4  air_ba937bf13d40fb24_2016-01-18    0               4
#
#                   air_area_name   latitude   longitude  air_area_name0  \
# 0  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               7
# 1  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               7
# 2  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               7
# 3  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               7
# 4  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               7
#
#    holiday_flg  holiday_flg2  avg_temperature  precipitation  \
# 0            0             0              4.3            0.0
# 1            0             0              6.0            0.0
# 2            0             0              5.6            0.0
# 3            0             1              6.5            0.0
# 4            0             0              2.8           67.0
#
#    high_temperature  low_temperature
# 0               9.7             -0.9
# 1              11.4              0.2
# 2              10.9              2.0
# 3              11.8              1.8
# 4               6.2              0.2

# %%
data_with_weather['rainning'] = (data_with_weather['precipitation'] > 0).astype(int)

# %%
air_visit = pd.merge(air_visit, data_with_weather[['store_id', 'rainning','visit_date','precipitation']], on = ['store_id', 'visit_date'], how = 'left')

# %%
air_visit['precipitation'].describe()
# Out:
# count    252108.000000
# mean          4.248645
# std          12.367214
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           2.000000
# max         208.000000
# Name: precipitation, dtype: float64

# %%
sns.distplot(air_visit['precipitation'])
# Out:
# <AxesSubplot:xlabel='precipitation', ylabel='Density'>

# %%
sns.scatterplot('precipitation','visitors', data = air_visit)
# Out:
# <AxesSubplot:xlabel='precipitation', ylabel='Density'>

# %% [markdown]
# 강수량과 전체 방문자수와는 관계가 없는 것 같다

# %%
air_visit[air_visit['precipitation'] > 100].describe()
# Out:
#          visitors         dow      month  rainning  precipitation
# count  652.000000  652.000000  652.00000     652.0     652.000000
# mean    14.182515    1.556748    8.15184       1.0     123.953221
# std     12.641900    2.114575    0.78774       0.0      19.481699
# min      1.000000    0.000000    5.00000       1.0     100.500000
# 25%      5.000000    0.000000    8.00000       1.0     106.500000
# 50%     10.000000    0.000000    8.00000       1.0     120.000000
# 75%     20.000000    2.000000    9.00000       1.0     141.000000
# max     77.000000    6.000000    9.00000       1.0     208.000000

# %%
sns.distplot(air_visit[air_visit['precipitation'] > 100]['visitors'])
# Out:
# <AxesSubplot:xlabel='visitors', ylabel='Density'>

# %%
ax = sns.distplot(air_visit[air_visit['precipitation'] < 100]['visitors'])
ax.set(xlim = (0,60))
# Out:
# [(0.0, 60.0)]

# %%
air_visit[air_visit['precipitation'] < 100]['visitors'].describe()
# Out:
# count    251454.000000
# mean         20.991287
# std          16.762845
# min           1.000000
# 25%           9.000000
# 50%          17.000000
# 75%          29.000000
# max         877.000000
# Name: visitors, dtype: float64

# %%
sns.barplot('rainning','visitors', data = air_visit)
# Out:
# <AxesSubplot:xlabel='rainning', ylabel='visitors'>

# %% [markdown]
# 비가 안올떄 평균 방문자 수가 더 높다

# %%
sns.barplot('rainning','visitors', data = air_visit, estimator = median)
# Out:
# <AxesSubplot:xlabel='rainning', ylabel='visitors'>

# %% [markdown]
# 비가 안올떄 방문자수에 대한 중간값이 높다

# %%
data = pd.merge(data, data_with_weather[['store_id', 'rainning','visit_date','precipitation']], on = ['store_id', 'visit_date'], how = 'left')

# %%
data['heavy_rain'] = (data['precipitation'] > 100).astype(int)

# %%
data['']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\tf_opencv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-baa9dcdad2de> in <module>
# ----> 1 data['']
#
# ~\anaconda3\envs\tf_opencv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\envs\tf_opencv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: ''

# %%
sns.barplot('rainning','visitors', data = data_with_weather, estimator = median)
# Out:
# <AxesSubplot:xlabel='rainning', ylabel='visitors'>

# %%
sns.barplot('rainning','visitors', data = data_with_weather)
# Out:
# <AxesSubplot:xlabel='rainning', ylabel='visitors'>

# %% [markdown]
# ## 예약 데이터 활용(해야됨)

# %%
air_reserve = air_reserve.rename(columns= {'reserve_visitors' : 'air_reserve_visitors'})
hpg_reserve = hpg_reserve.rename(columns= {'reserve_visitors' : 'hpg_reserve_visitors'})
hpg_air_reserve = pd.merge(air_reserve, hpg_reserve[['store_id','visit_date','hpg_reserve_visitors']], on = ["store_id", "visit_date"], how = "left").fillna(0)
hpg_air_reserve = pd.merge(air_visit[['store_id','visit_date','visitors']], hpg_air_reserve, on = ["store_id", "visit_date"], how = "left").fillna(0)

# %%
import math

# %%
data['air_store_id2'] = lbl.fit_transform(data['store_id'])

# %%
data['id_dow_visitor_max']= data.groupby(['store_id', 'dow'])['visitors'].transform(max)
data['id_dow_visitor_min']= data.groupby(['store_id', 'dow'])['visitors'].transform(min)
data['id_dow_visitor_mean']= data.groupby(['store_id', 'dow'])['visitors'].transform(np.mean)

# %%
data['genre_dow_visitor_min']= data.groupby(['air_genre_name', 'dow'])['visitors'].transform(min)
data['genre_dow_visitor_max']= data.groupby(['air_genre_name', 'dow'])['visitors'].transform(max)
data['genre_dow_visitor_mean']= data.groupby(['air_genre_name', 'dow'])['visitors'].transform(np.mean)

# %% [markdown]
# ## 모델 구성 및 결과 예측

# %%
train_size = len(air_visit)
train = data[:train_size]
test = data[train_size:]

# %%
train.columns
# Out:
# Index(['store_id', 'visit_date', 'visitors', 'id', 'dow', 'month',
#        'air_genre_name', 'air_area_name', 'latitude', 'longitude',
#        'air_area_name0', 'air_genre_name0', 'genre_count_per_area',
#        'holiday_flg', 'holiday_flg2', 'golden_week', 'rainning',
#        'precipitation', 'heavy_rain', 'air_store_id2', 'id_dow_visitor_max',
#        'id_dow_visitor_min', 'id_dow_visitor_mean', 'genre_dow_visitor_min',
#        'genre_dow_visitor_max', 'genre_dow_visitor_mean',
#        'restaurants_per_area'],
#       dtype='object')

# %%
col = ['dow', 'air_genre_name', 'air_area_name0', 'holiday_flg', 'holiday_flg2', 'month','golden_week',
      'genre_dow_visitor_min', 'genre_dow_visitor_max','genre_dow_visitor_mean','id_dow_visitor_max','id_dow_visitor_min',
      'id_dow_visitor_mean','genre_count_per_area','air_store_id2', 'rainning','heavy_rain']
col
# Out:
# ['dow',
#  'air_genre_name',
#  'air_area_name0',
#  'holiday_flg',
#  'holiday_flg2',
#  'month',
#  'golden_week',
#  'genre_dow_visitor_min',
#  'genre_dow_visitor_max',
#  'genre_dow_visitor_mean',
#  'id_dow_visitor_max',
#  'id_dow_visitor_min',
#  'id_dow_visitor_mean',
#  'genre_count_per_area',
#  'air_store_id2',
#  'rainning',
#  'heavy_rain']

# %%
#col = ['dow', 'air_genre_name', 'air_area_name0','genre_count_per_area', 'holiday_flg', 'holiday_flg2', 'month', 'golden_week',
#      'id_dow_visitor_max','id_dow_visitor_min', 'id_dow_visitor_mean','air_store_id2']

# %%
import lightgbm as lgb

# %%
params = {
    'learning_rate': 0.02,
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'rmse',
    'sub_feature': 0.7,
    'num_leaves': 60,
    'min_data': 100,
    'min_hessian': 1,
    'verbose': -1,
}

# %%
lgb_train = lgb.Dataset(train[col], train['visitors'])
lgb_test = lgb.Dataset(test[col], test['visitors'])

gbm = lgb.train(params,lgb_train,2300)
pred = gbm.predict(test[col])

# %%
test['visitors'] = np.expm1(pred)

# %%
sub = test[['id','visitors']].copy()
sub.to_csv('submission.csv', index=False)

# %% [markdown]
# ## 이상치 Reservation(해야됨)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
air_reserve.head()
# Out:
#                store_id       visit_datetime     reserve_datetime  \
# 0  air_877f79706adbfb06  2016-01-01 19:00:00  2016-01-01 16:00:00
# 1  air_db4b38ebe7a7ceff  2016-01-01 19:00:00  2016-01-01 19:00:00
# 2  air_db4b38ebe7a7ceff  2016-01-01 19:00:00  2016-01-01 19:00:00
# 3  air_877f79706adbfb06  2016-01-01 20:00:00  2016-01-01 16:00:00
# 4  air_db80363d35f10926  2016-01-01 20:00:00  2016-01-01 01:00:00
#
#    reserve_visitors  visit_date reserve_date  dow
# 0                 1  2016-01-01   2016-01-01    4
# 1                 3  2016-01-01   2016-01-01    4
# 2                 6  2016-01-01   2016-01-01    4
# 3                 2  2016-01-01   2016-01-01    4
# 4                 5  2016-01-01   2016-01-01    4

# %%
f, ax = plt.subplots(1, 2, figsize= (12, 4))
sns.countplot('reserve_visitors', data = air_reserve, ax = ax[0])
ax[0].xaxis.set_major_locator(ticker.MultipleLocator(10))
ax[0].xaxis.set_major_formatter(ticker.ScalarFormatter())
sns.countplot('reserve_visitors', data = hpg_reserve, ax = ax[1])
ax[1].xaxis.set_major_locator(ticker.MultipleLocator(10))
ax[1].xaxis.set_major_formatter(ticker.ScalarFormatter())
plt.tight_layout()
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# 예약수의 차이 => 식당수도 다름..

# %%
air_reserve = air_reserve.rename(columns= {'reserve_visitors' : 'air_reserve_visitors'})
hpg_reserve = hpg_reserve.rename(columns= {'reserve_visitors' : 'hpg_reserve_visitors'})

# %%
air_store.head()
# Out:
#                store_id  air_genre_name                 air_area_name  \
# 0  air_0f0cdeee6c9bf3d7               6  Hyōgo-ken Kōbe-shi Kumoidōri
# 1  air_7cc17a324ae5c7dc               6  Hyōgo-ken Kōbe-shi Kumoidōri
# 2  air_fee8dcf4d619598e               6  Hyōgo-ken Kōbe-shi Kumoidōri
# 3  air_a17f0778617c76e2               6  Hyōgo-ken Kōbe-shi Kumoidōri
# 4  air_83db5aff8f50478e               6  Tōkyō-to Minato-ku Shibakōen
#
#     latitude   longitude  air_area_name0  genre_count_per_area air_genre_name0
# 0  34.695124  135.197853               3                     4  Italian French
# 1  34.695124  135.197853               3                     4  Italian French
# 2  34.695124  135.197853               3                     4  Italian French
# 3  34.695124  135.197853               3                     4  Italian French
# 4  35.658068  139.751599               7                    13  Italian French

# %%
hpg_air_reserve['store_id'].nunique()
# Out:
# 314

# %%
air_visit['store_id'].nunique()
# Out:
# 829

# %%
hpg_air_reserve = pd.merge(air_reserve, hpg_reserve[['store_id','visit_date','hpg_reserve_visitors']], on = ["store_id", "visit_date"], how = "left").fillna(0)
hpg_air_reserve = pd.merge(air_visit[['store_id','visit_date','visitors']], hpg_air_reserve, on = ["store_id", "visit_date"], how = "left").fillna(0)
#hpg_air_reserve = pd.merge(hpg_air_reserve, air_store[['store_id','air_genre_name','air_genre_name0','air_area_name','air_area_name0']], on = ["store_id"], how = "left")

# %%
f, ax = plt.subplots(1, 2, figsize= (12, 4))
sns.countplot('air_genre_name', data = hpg_air_reserve[hpg_air_reserve['hpg_reserve_visitors'] != 0], ax = ax[0])
ax[0].set_title("hpg_with_air")
sns.countplot('air_genre_name', data = hpg_air_reserve[hpg_air_reserve['hpg_reserve_visitors'] == 0], ax = ax[1])
ax[1].set_title("onlt_air")
plt.tight_layout()
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
hpg_air_reserve[(hpg_air_reserve['air_genre_name'] == 0) | (hpg_air_reserve['air_genre_name'] == 5)]
# Out:
#                     store_id       visit_datetime     reserve_datetime  \
# 83020   air_6b65745d432fd77f  2017-02-21 19:00:00  2017-02-21 14:00:00
# 85431   air_6b65745d432fd77f  2017-02-25 18:00:00  2017-02-23 12:00:00
# 90210   air_10bbe8acd943d8f6  2017-03-06 20:00:00  2017-01-15 00:00:00
# 90239   air_10bbe8acd943d8f6  2017-03-06 21:00:00  2017-01-18 17:00:00
# 103051  air_6b65745d432fd77f  2017-03-29 20:00:00  2017-03-29 14:00:00
#
#         air_reserve_visitors  visit_date reserve_date  dow  \
# 83020                      7  2017-02-21   2017-02-21    1
# 85431                      3  2017-02-25   2017-02-23    5
# 90210                     40  2017-03-06   2017-01-15    0
# 90239                     12  2017-03-06   2017-01-18    0
# 103051                     4  2017-03-29   2017-03-29    2
#
#         hpg_reserve_visitors  visitors  air_genre_name        air_genre_name0  \
# 83020                    0.0      19.0               5  International cuisine
# 85431                    0.0      48.0               5  International cuisine
# 90210                    0.0      12.0               0                  Asian
# 90239                    0.0      12.0               0                  Asian
# 103051                   0.0      17.0               5  International cuisine
#
#                       air_area_name  air_area_name0
# 83020   Tōkyō-to Shibuya-ku Shibuya               7
# 85431   Tōkyō-to Shibuya-ku Shibuya               7
# 90210   Tōkyō-to Shibuya-ku Shibuya               7
# 90239   Tōkyō-to Shibuya-ku Shibuya               7
# 103051  Tōkyō-to Shibuya-ku Shibuya               7

# %%
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='air_genre_name', ylabel='count'>

# %%
sns.countplot('air_genre_name', data = hpg_air_reserve[hpg_air_reserve['hpg_reserve_visitors'] == 0])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='air_genre_name', ylabel='count'>

# %%
hpg_air_reserve
# Out:
#                     store_id       visit_datetime     reserve_datetime  \
# 0       air_877f79706adbfb06  2016-01-01 19:00:00  2016-01-01 16:00:00
# 1       air_db4b38ebe7a7ceff  2016-01-01 19:00:00  2016-01-01 19:00:00
# 2       air_db4b38ebe7a7ceff  2016-01-01 19:00:00  2016-01-01 19:00:00
# 3       air_877f79706adbfb06  2016-01-01 20:00:00  2016-01-01 16:00:00
# 4       air_db80363d35f10926  2016-01-01 20:00:00  2016-01-01 01:00:00
# ...                      ...                  ...                  ...
# 117082  air_db4b38ebe7a7ceff  2017-05-29 18:00:00  2017-04-17 19:00:00
# 117083  air_1033310359ceeac1  2017-05-30 23:00:00  2017-04-19 17:00:00
# 117084  air_877f79706adbfb06  2017-05-31 20:00:00  2017-04-12 23:00:00
# 117085  air_900d755ebd2f7bbd  2017-05-31 20:00:00  2017-04-19 16:00:00
# 117086  air_3cad29d1a23209d2  2017-05-31 21:00:00  2017-04-22 10:00:00
#
#         reserve_visitors  visit_date reserve_date  dow  hpg_reserve_visitors
# 0                      1  2016-01-01   2016-01-01    4                   0.0
# 1                      3  2016-01-01   2016-01-01    4                   0.0
# 2                      6  2016-01-01   2016-01-01    4                   0.0
# 3                      2  2016-01-01   2016-01-01    4                   0.0
# 4                      5  2016-01-01   2016-01-01    4                   4.0
# ...                  ...         ...          ...  ...                   ...
# 117082                 6  2017-05-29   2017-04-17    0                   0.0
# 117083                 8  2017-05-30   2017-04-19    1                   0.0
# 117084                 3  2017-05-31   2017-04-12    2                   0.0
# 117085                10  2017-05-31   2017-04-19    2                   0.0
# 117086                 3  2017-05-31   2017-04-22    2                   0.0
#
# [117087 rows x 8 columns]

# %%
air_reserve['reserve_visitors'].describe()
# Out:
# count    92378.000000
# mean         4.481749
# std          4.919669
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          5.000000
# max        100.000000
# Name: reserve_visitors, dtype: float64

# %%
air_reserve['reserve_visitors'].mode()
# Out:
# 0    2
# dtype: int64

# %%
air_reserve
hpg_reserve

# %%
def diff_of_days(day1, day2):
    days = (parse(day1[:10]) - parse(day2[:10])).days
    return days

# %%
air_reserve
# Out:
#                    store_id       visit_datetime     reserve_datetime  \
# 0      air_877f79706adbfb06  2016-01-01 19:00:00  2016-01-01 16:00:00
# 1      air_db4b38ebe7a7ceff  2016-01-01 19:00:00  2016-01-01 19:00:00
# 2      air_db4b38ebe7a7ceff  2016-01-01 19:00:00  2016-01-01 19:00:00
# 3      air_877f79706adbfb06  2016-01-01 20:00:00  2016-01-01 16:00:00
# 4      air_db80363d35f10926  2016-01-01 20:00:00  2016-01-01 01:00:00
# ...                     ...                  ...                  ...
# 92373  air_db4b38ebe7a7ceff  2017-05-29 18:00:00  2017-04-17 19:00:00
# 92374  air_1033310359ceeac1  2017-05-30 23:00:00  2017-04-19 17:00:00
# 92375  air_877f79706adbfb06  2017-05-31 20:00:00  2017-04-12 23:00:00
# 92376  air_900d755ebd2f7bbd  2017-05-31 20:00:00  2017-04-19 16:00:00
# 92377  air_3cad29d1a23209d2  2017-05-31 21:00:00  2017-04-22 10:00:00
#
#        reserve_visitors  visit_date reserve_date  dow
# 0                     1  2016-01-01   2016-01-01    4
# 1                     3  2016-01-01   2016-01-01    4
# 2                     6  2016-01-01   2016-01-01    4
# 3                     2  2016-01-01   2016-01-01    4
# 4                     5  2016-01-01   2016-01-01    4
# ...                 ...         ...          ...  ...
# 92373                 6  2017-05-29   2017-04-17    0
# 92374                 8  2017-05-30   2017-04-19    1
# 92375                 3  2017-05-31   2017-04-12    2
# 92376                10  2017-05-31   2017-04-19    2
# 92377                 3  2017-05-31   2017-04-22    2
#
# [92378 rows x 7 columns]

# %%
from datetime import datetime

air_reserve['differ']  = pd.to_datetime(air_reserve['visit_date']) - pd.to_datetime(air_reserve['reserve_date'])

# %%
air_reserve['differ'] = air_reserve['differ'].astype(str)
air_reserve['differ'] = air_reserve['differ'].apply(lambda x : x.split(" ")[0])

# %%
air_reserve['differ'] = air_reserve['differ'].astype(int)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
ax = sns.countplot(air_reserve['differ'])
ax.xaxis.set_major_locator(ticker.MultipleLocator(20))
ax.xaxis.set_major_formatter(ticker.ScalarFormatter())
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
famous_res_id = air_reserve[air_reserve['differ'] > 300]['store_id'].unique()

# %%
famous_res_id
# Out:
# array(['air_a17f0778617c76e2', 'air_f068442ebb6c246c',
#        'air_2a485b92210c98b5', 'air_6b9fa44a9cf504a1',
#        'air_e7fbee4e3cfe65c5', 'air_f911308e19d64236'], dtype=object)

# %%
air_reserve[(air_reserve['differ'] > 300) & (air_reserve['store_id'] == 'air_a17f0778617c76e2')]
# Out:
#                    store_id       visit_datetime     reserve_datetime  \
# 21547  air_a17f0778617c76e2  2016-11-11 18:00:00  2016-01-05 17:00:00
# 21570  air_a17f0778617c76e2  2016-11-11 18:00:00  2016-01-08 21:00:00
# 21589  air_a17f0778617c76e2  2016-11-11 18:00:00  2016-01-07 21:00:00
# 21743  air_a17f0778617c76e2  2016-11-11 19:00:00  2016-01-06 13:00:00
# 21744  air_a17f0778617c76e2  2016-11-11 19:00:00  2016-01-12 00:00:00
# 21746  air_a17f0778617c76e2  2016-11-11 19:00:00  2016-01-13 15:00:00
# 21747  air_a17f0778617c76e2  2016-11-11 19:00:00  2016-01-07 17:00:00
# 21748  air_a17f0778617c76e2  2016-11-11 19:00:00  2016-01-09 01:00:00
# 21750  air_a17f0778617c76e2  2016-11-11 19:00:00  2016-01-04 21:00:00
# 21752  air_a17f0778617c76e2  2016-11-11 19:00:00  2016-01-10 14:00:00
# 21753  air_a17f0778617c76e2  2016-11-11 19:00:00  2016-01-10 10:00:00
# 21755  air_a17f0778617c76e2  2016-11-11 19:00:00  2016-01-12 12:00:00
# 21756  air_a17f0778617c76e2  2016-11-11 19:00:00  2016-01-15 19:00:00
# 21757  air_a17f0778617c76e2  2016-11-11 19:00:00  2016-01-09 18:00:00
# 21758  air_a17f0778617c76e2  2016-11-11 19:00:00  2016-01-14 17:00:00
# 21759  air_a17f0778617c76e2  2016-11-11 19:00:00  2016-01-09 21:00:00
# 21760  air_a17f0778617c76e2  2016-11-11 19:00:00  2016-01-11 21:00:00
# 21761  air_a17f0778617c76e2  2016-11-11 19:00:00  2016-01-06 18:00:00
# 21763  air_a17f0778617c76e2  2016-11-11 19:00:00  2016-01-14 13:00:00
# 21764  air_a17f0778617c76e2  2016-11-11 19:00:00  2016-01-15 13:00:00
# 21765  air_a17f0778617c76e2  2016-11-11 19:00:00  2016-01-02 15:00:00
# 21766  air_a17f0778617c76e2  2016-11-11 19:00:00  2016-01-04 21:00:00
# 21767  air_a17f0778617c76e2  2016-11-11 19:00:00  2016-01-08 20:00:00
# 21768  air_a17f0778617c76e2  2016-11-11 19:00:00  2016-01-12 20:00:00
# 21769  air_a17f0778617c76e2  2016-11-11 19:00:00  2016-01-14 22:00:00
#
#        reserve_visitors  visit_date reserve_date  dow  differ
# 21547                16  2016-11-11   2016-01-05    4     311
# 21570                 9  2016-11-11   2016-01-08    4     308
# 21589                 7  2016-11-11   2016-01-07    4     309
# 21743                 5  2016-11-11   2016-01-06    4     310
# 21744                 4  2016-11-11   2016-01-12    4     304
# 21746                 4  2016-11-11   2016-01-13    4     303
# 21747                 6  2016-11-11   2016-01-07    4     309
# 21748                 4  2016-11-11   2016-01-09    4     307
# 21750                72  2016-11-11   2016-01-04    4     312
# 21752                 2  2016-11-11   2016-01-10    4     306
# 21753                 5  2016-11-11   2016-01-10    4     306
# 21755                 8  2016-11-11   2016-01-12    4     304
# 21756                 2  2016-11-11   2016-01-15    4     301
# 21757                 2  2016-11-11   2016-01-09    4     307
# 21758                 2  2016-11-11   2016-01-14    4     302
# 21759                 3  2016-11-11   2016-01-09    4     307
# 21760                 5  2016-11-11   2016-01-11    4     305
# 21761                 2  2016-11-11   2016-01-06    4     310
# 21763                10  2016-11-11   2016-01-14    4     302
# 21764                 2  2016-11-11   2016-01-15    4     301
# 21765                 8  2016-11-11   2016-01-02    4     314
# 21766                50  2016-11-11   2016-01-04    4     312
# 21767                 3  2016-11-11   2016-01-08    4     308
# 21768                 4  2016-11-11   2016-01-12    4     304
# 21769                 3  2016-11-11   2016-01-14    4     302

# %%
data[(data['store_id'] == 'air_a17f0778617c76e2') & (data['visit_date'] == '2016-11-11')]
# Out:
# Empty DataFrame
# Columns: [store_id, visit_date, visitors, id, dow, air_genre_name, air_area_name, latitude, longitude, air_area_name0, genre_count_per_area, holiday_flg, holiday_flg2, golden_week, month]
# Index: []

# %%
data[(data['store_id'] == 'air_a17f0778617c76e2') & (data['visit_date'] == '2016-11-11')]

# %%
data[data['store_id'] == 'air_a17f0778617c76e2'].groupby(['visit_date'])['visitors'].sum().plot()
# Out:
# <AxesSubplot:xlabel='visit_date'>

# %%
air_visit[air_visit['store_id'].isin(famous_res_id)].groupby('store_id')['visitors'].sum()
# Out:
# store_id
# air_2a485b92210c98b5     2402
# air_6b9fa44a9cf504a1     2513
# air_a17f0778617c76e2     2096
# air_e7fbee4e3cfe65c5    10220
# air_f068442ebb6c246c     3735
# air_f911308e19d64236    14816
# Name: visitors, dtype: int64

# %%
air_visit.groupby('store_id')['visitors'].sum().sort_values().describe()
# Out:
# count      829.000000
# mean      6378.351025
# std       3919.690328
# min        190.000000
# 25%       3328.000000
# 50%       5474.000000
# 75%       8791.000000
# max      18717.000000
# Name: visitors, dtype: float64

# %%
data[data['store_id'] == "air_a17f0778617c76e2"]
# Out:
#                     store_id  visit_date  visitors  \
# 108729  air_a17f0778617c76e2  2017-03-07  3.044522
# 108730  air_a17f0778617c76e2  2017-03-08  3.465736
# 108731  air_a17f0778617c76e2  2017-03-09  2.944439
# 108732  air_a17f0778617c76e2  2017-03-10  4.276666
# 108733  air_a17f0778617c76e2  2017-03-11  4.595120
# ...                      ...         ...       ...
# 272578  air_a17f0778617c76e2  2017-05-27  0.000000
# 272579  air_a17f0778617c76e2  2017-05-28  0.000000
# 272580  air_a17f0778617c76e2  2017-05-29  0.000000
# 272581  air_a17f0778617c76e2  2017-05-30  0.000000
# 272582  air_a17f0778617c76e2  2017-05-31  0.000000
#
#                                      id  dow  air_genre_name  \
# 108729  air_a17f0778617c76e2_2017-03-07    1               6
# 108730  air_a17f0778617c76e2_2017-03-08    2               6
# 108731  air_a17f0778617c76e2_2017-03-09    3               6
# 108732  air_a17f0778617c76e2_2017-03-10    4               6
# 108733  air_a17f0778617c76e2_2017-03-11    5               6
# ...                                 ...  ...             ...
# 272578  air_a17f0778617c76e2_2017-05-27    5               6
# 272579  air_a17f0778617c76e2_2017-05-28    6               6
# 272580  air_a17f0778617c76e2_2017-05-29    0               6
# 272581  air_a17f0778617c76e2_2017-05-30    1               6
# 272582  air_a17f0778617c76e2_2017-05-31    2               6
#
#                        air_area_name   latitude   longitude  air_area_name0  \
# 108729  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197853               3
# 108730  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197853               3
# 108731  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197853               3
# 108732  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197853               3
# 108733  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197853               3
# ...                              ...        ...         ...             ...
# 272578  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197853               3
# 272579  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197853               3
# 272580  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197853               3
# 272581  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197853               3
# 272582  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197853               3
#
#         genre_count_per_area  holiday_flg  holiday_flg2  golden_week  month
# 108729                     4            0             0            0      3
# 108730                     4            0             0            0      3
# 108731                     4            0             0            0      3
# 108732                     4            0             0            0      3
# 108733                     4            0             1            0      3
# ...                      ...          ...           ...          ...    ...
# 272578                     4            0             1            0      5
# 272579                     4            0             1            0      5
# 272580                     4            0             0            0      5
# 272581                     4            0             0            0      5
# 272582                     4            0             0            0      5
#
# [86 rows x 15 columns]

# %%
air_reserve[air_reserve['store_id'].isin(famous_res_id)]
# Out:
#                    store_id       visit_datetime     reserve_datetime  \
# 57     air_f911308e19d64236  2016-01-04 18:00:00  2016-01-04 15:00:00
# 99     air_f911308e19d64236  2016-01-06 12:00:00  2016-01-06 11:00:00
# 100    air_f911308e19d64236  2016-01-06 13:00:00  2016-01-04 11:00:00
# 135    air_f911308e19d64236  2016-01-06 20:00:00  2016-01-06 17:00:00
# 140    air_6b9fa44a9cf504a1  2016-01-06 23:00:00  2016-01-06 23:00:00
# ...                     ...                  ...                  ...
# 92299  air_f911308e19d64236  2017-05-20 11:00:00  2017-01-04 17:00:00
# 92317  air_2a485b92210c98b5  2017-05-21 00:00:00  2017-04-18 21:00:00
# 92322  air_2a485b92210c98b5  2017-05-21 19:00:00  2017-04-13 19:00:00
# 92334  air_6b9fa44a9cf504a1  2017-05-24 19:00:00  2017-04-06 18:00:00
# 92365  air_f911308e19d64236  2017-05-28 12:00:00  2017-04-22 15:00:00
#
#        reserve_visitors  visit_date reserve_date  dow  differ
# 57                    2  2016-01-04   2016-01-04    0       0
# 99                    2  2016-01-06   2016-01-06    2       0
# 100                   2  2016-01-06   2016-01-04    2       2
# 135                   2  2016-01-06   2016-01-06    2       0
# 140                   2  2016-01-06   2016-01-06    2       0
# ...                 ...         ...          ...  ...     ...
# 92299                29  2017-05-20   2017-01-04    5     136
# 92317                 7  2017-05-21   2017-04-18    6      33
# 92322                28  2017-05-21   2017-04-13    6      38
# 92334                 4  2017-05-24   2017-04-06    2      48
# 92365                 6  2017-05-28   2017-04-22    6      36
#
# [3643 rows x 8 columns]

# %% [markdown]
# # 추가분

# %% [markdown]
# air_area_name을 특성으로 쓰기위해 라벨인코딩 하는 부분(인코딩하는 부분에 같이넣으면 좋을듯)

# %%
data['air_area_name'] = lbl.fit_transform(data['air_area_name'])

# %% [markdown]
# 지역마다 총 가게 개수 -> 5-3에서 추가 하면 될듯

# %%
data['restaurants_per_area'] = data.groupby(['air_area_name'])['store_id'].transform('count')
data['restaurants_per_area'] = np.log1p(data['restaurants_per_area'])
data['restaurants_per_area']
# Out:
# 0         9.722325
# 1         9.722325
# 2         9.722325
# 3         9.722325
# 4         9.722325
#             ...
# 284122    7.618742
# 284123    7.618742
# 284124    7.618742
# 284125    7.618742
# 284126    7.618742
# Name: restaurants_per_area, Length: 284127, dtype: float64

# %% [markdown]
# ## hitmap

# %%
corrMatrix=data[['restaurants_per_area', 'precipitation', 'genre_count_per_area', 'id_dow_visitor_mean', 'id_dow_visitor_min',
                  'id_dow_visitor_max', 'genre_dow_visitor_mean', 'genre_dow_visitor_max',
                  'month', 'dow', 'visitors']].corr()

sns.set(font_scale=1.10)
plt.figure(figsize=(10, 10))

sns.heatmap(corrMatrix, vmax=.8, linewidths=0.01,
            square=True,annot=True,cmap='viridis',linecolor="white")
plt.title('Correlation between features');
plt.show()

# %% [markdown]
# # 바뀐 부분
# genre_dow_visitor_min은 지우나 안지우나 관계없음.
# 어차피 0이라서 영향 x

# %%
col = ['dow', 'air_genre_name', 'air_area_name', 'holiday_flg', 'holiday_flg2', 'month','golden_week', 'genre_dow_visitor_max','genre_dow_visitor_mean','id_dow_visitor_max','id_dow_visitor_min',
      'id_dow_visitor_mean','genre_count_per_area','air_store_id2', 'rainning','heavy_rain', 'restaurants_per_area']
col
# Out:
# ['dow',
#  'air_genre_name',
#  'air_area_name',
#  'holiday_flg',
#  'holiday_flg2',
#  'month',
#  'golden_week',
#  'genre_dow_visitor_max',
#  'genre_dow_visitor_mean',
#  'id_dow_visitor_max',
#  'id_dow_visitor_min',
#  'id_dow_visitor_mean',
#  'genre_count_per_area',
#  'air_store_id2',
#  'rainning',
#  'heavy_rain',
#  'restaurants_per_area']
