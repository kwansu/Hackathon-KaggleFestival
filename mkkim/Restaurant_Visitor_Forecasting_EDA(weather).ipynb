# %% [markdown]
# <a href="https://colab.research.google.com/github/mkkim007/Hackathon-KaggleFestival/blob/main/mkkim/Restaurant_Visitor_Forecasting_EDA(weather).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !mkdir /content/data
# !mkdir /content/Weather

# %%
# !cp /content/gdrive/MyDrive/Data/recruit-restaurant-visitor-forecasting.zip /content/data

# %%
# !unzip -qq /content/data/recruit-restaurant-visitor-forecasting.zip -d /content/data

# %%
# !cp /content/gdrive/MyDrive/Data/recruit-restaurant-visitor-forecasting-weather.zip /content/Weather
# !unzip -qq /content/Weather/recruit-restaurant-visitor-forecasting-weather.zip -d /content/Weather

# %%
import warnings
warnings.filterwarnings("ignore")

import time
import numpy as np
import pandas as pd
from dateutil.parser import parse
import datetime
from datetime import date, timedelta
from sklearn.preprocessing import LabelEncoder

import missingno as msno

import folium
from folium import plugins as folium_plugins
from folium import features


from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import KFold, cross_val_score
import xgboost as xgb
import lightgbm as lgb
from scipy.stats import norm #Analysis 
from scipy import stats #Analysis 
import scipy as sp
from sklearn.preprocessing import StandardScaler #Analysis 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
import gc

from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score , cross_validate

# %% [markdown]
# # 날씨 데이터

# %%
pd.set_option('display.expand_frame_repr', False)
warnings.simplefilter(action='ignore', category=FutureWarning)

weather_set_dir = '/content/Weather/'
weather_data_dir = '{}/1-1-16_5-31-17_Weather/1-1-16_5-31-17_Weather/'.format(weather_set_dir)
original_data_dir = '/content/data'

weather_columns = [
    'avg_temperature', 'high_temperature', 'low_temperature', 'precipitation',
    'hours_sunlight', 'solar_radiation', 'deepest_snowfall', 'total_snowfall', 'avg_wind_speed',
    'avg_vapor_pressure', 'avg_local_pressure', 'avg_humidity', 'avg_sea_pressure', 
    'cloud_cover'
]

# %%
air_store_info = pd.read_csv('{}/air_store_info_with_nearest_active_station.csv'.format(weather_set_dir))
hpg_store_info = pd.read_csv('{}/hpg_store_info_with_nearest_active_station.csv'.format(weather_set_dir))

air_station_distances = pd.read_csv('{}/air_station_distances.csv'.format(weather_set_dir))
hpg_station_distances = pd.read_csv('{}/hpg_station_distances.csv'.format(weather_set_dir))

weather_stations = pd.read_csv('{}/weather_stations.csv'.format(weather_set_dir))
nearby_active_stations = pd.read_csv('{}/nearby_active_stations.csv'.format(weather_set_dir))
feature_manifest = pd.read_csv('{}/feature_manifest.csv'.format(weather_set_dir))

# %% [markdown]
# 기존에 있는 info와 날씨 데이터에 있는 info가 같은지 확인!

# %%
original_as_info = pd.read_csv('{}/air_store_info.csv.zip'.format(original_data_dir))
original_hs_info = pd.read_csv('{}/hpg_store_info.csv.zip'.format(original_data_dir))

display(original_as_info.head(5))
display(original_hs_info.head(5))

print('Air Equal: {}'.format(original_as_info.equals(air_store_info[original_as_info.columns])))
print('HPG Equal: {}'.format(original_hs_info.equals(hpg_store_info[original_hs_info.columns])))
# Out:
#            air_store_id  air_genre_name                 air_area_name   latitude   longitude
# 0  air_0f0cdeee6c9bf3d7  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197852
# 1  air_7cc17a324ae5c7dc  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197852
# 2  air_fee8dcf4d619598e  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197852
# 3  air_a17f0778617c76e2  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197852
# 4  air_83db5aff8f50478e  Italian/French  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
#            hpg_store_id  hpg_genre_name                  hpg_area_name   latitude   longitude
# 0  hpg_6622b62385aec8bf  Japanese style  Tōkyō-to Setagaya-ku Taishidō  35.643675  139.668221
# 1  hpg_e9e068dd49c5fa00  Japanese style  Tōkyō-to Setagaya-ku Taishidō  35.643675  139.668221
# 2  hpg_2976f7acb4b3a3bc  Japanese style  Tōkyō-to Setagaya-ku Taishidō  35.643675  139.668221
# 3  hpg_e51a522e098f024c  Japanese style  Tōkyō-to Setagaya-ku Taishidō  35.643675  139.668221
# 4  hpg_e3d0e1519894f275  Japanese style  Tōkyō-to Setagaya-ku Taishidō  35.643675  139.668221
# Air Equal: True
# HPG Equal: True

# %%
air_nearest = pd.read_csv(                                                                                                                
        '{}air_store_info_with_nearest_active_station.csv'.format(weather_set_dir))                                                              
unique_air_store_ids = list(data.store_id.unique())
weather_keep_columns = ['precipitation', 'avg_temperature']
dataset_with_weather = data.copy()
for column in weather_keep_columns:                                                                                                       
    dataset_with_weather[column] = np.nan

# %%
dataset_with_weather
# Out:
#                     store_id  visit_date  visitors                               id  dow  air_genre_name                 air_area_name   latitude   longitude  air_area_name0  holiday_flg  holiday_flg2  precipitation  avg_temperature
# 0       air_ba937bf13d40fb24  2016-01-13  3.258097  air_ba937bf13d40fb24_2016-01-13    2               4  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               7            0             0            NaN              NaN
# 1       air_ba937bf13d40fb24  2016-01-14  3.496508  air_ba937bf13d40fb24_2016-01-14    3               4  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               7            0             0            NaN              NaN
# 2       air_ba937bf13d40fb24  2016-01-15  3.401197  air_ba937bf13d40fb24_2016-01-15    4               4  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               7            0             0            NaN              NaN
# 3       air_ba937bf13d40fb24  2016-01-16  3.135494  air_ba937bf13d40fb24_2016-01-16    5               4  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               7            0             1            NaN              NaN
# 4       air_ba937bf13d40fb24  2016-01-18  1.945910  air_ba937bf13d40fb24_2016-01-18    0               4  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               7            0             0            NaN              NaN
# ...                      ...         ...       ...                              ...  ...             ...                           ...        ...         ...             ...          ...           ...            ...              ...
# 284122  air_fff68b929994bfbd  2017-05-27  0.000000  air_fff68b929994bfbd_2017-05-27    5               1     Tōkyō-to Nakano-ku Nakano  35.708146  139.666288               7            0             1            NaN              NaN
# 284123  air_fff68b929994bfbd  2017-05-28  0.000000  air_fff68b929994bfbd_2017-05-28    6               1     Tōkyō-to Nakano-ku Nakano  35.708146  139.666288               7            0             1            NaN              NaN
# 284124  air_fff68b929994bfbd  2017-05-29  0.000000  air_fff68b929994bfbd_2017-05-29    0               1     Tōkyō-to Nakano-ku Nakano  35.708146  139.666288               7            0             0            NaN              NaN
# 284125  air_fff68b929994bfbd  2017-05-30  0.000000  air_fff68b929994bfbd_2017-05-30    1               1     Tōkyō-to Nakano-ku Nakano  35.708146  139.666288               7            0             0            NaN              NaN
# 284126  air_fff68b929994bfbd  2017-05-31  0.000000  air_fff68b929994bfbd_2017-05-31    2               1     Tōkyō-to Nakano-ku Nakano  35.708146  139.666288               7            0             0            NaN              NaN
#
# [284127 rows x 14 columns]

# %%
print(len(air_nearest['air_store_id'].unique()))
print(len(data['store_id'].unique()))
# Out:
# 829
# 829

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   visit_date          517 non-null    datetime64[ns]
#  1   avg_temperature     517 non-null    float64
#  2   high_temperature    517 non-null    float64
#  3   low_temperature     517 non-null    float64
#  4   precipitation       268 non-null    float64
#  5   hours_sunlight      517 non-null    float64
#  6   solar_radiation     517 non-null    float64
#  7   deepest_snowfall    4 non-null      float64
#  8   total_snowfall      1 non-null      float64
#  9   avg_wind_speed      517 non-null    float64
#  10  avg_vapor_pressure  516 non-null    float64
#  11  avg_local_pressure  517 non-null    float64
#  12  avg_humidity        516 non-null    float64
#  13  avg_sea_pressure    517 non-null    float64
#  14  cloud_cover         517 non-null    float64
# dtypes: datetime64[ns](1), float64(14)
# memory usage: 60.7 KB

# %%
for air_id in unique_air_store_ids:                                                                                                       
    station = air_nearest[air_nearest.air_store_id == air_id].station_id.iloc[0]

    weather_data = pd.read_csv(weather_data_dir + station + '.csv', parse_dates=['calendar_date']).rename(columns={'calendar_date': 'visit_date'})                                                                                                                                           
    data['visit_date'] = pd.to_datetime(data['visit_date'])                                                                                                                                          
    this_store = data.store_id == air_id 
    print( data[this_store]['visit_date'])
                                                                                              
    merged = data[this_store].merge(weather_data, on='visit_date', how='left')                                                         
                                                                                                                                              
    for column in weather_keep_columns:                                                                                                   
        dataset_with_weather.loc[this_store, column] = merged[column]
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 125763   2016-01-09
#             ...
# 262204   2017-05-27
# 262205   2017-05-28
# 262206   2017-05-29
# 262207   2017-05-30
# 262208   2017-05-31
# Name: visit_date, Length: 411, dtype: datetime64[ns]
# 126131   2016-01-05
# 126132   2016-01-06
# 126133   2016-01-07
# 126134   2016-01-08
# 126135   2016-01-09
#             ...
# 280885   2017-05-27
# 280886   2017-05-28
# 280887   2017-05-29
# 280888   2017-05-30
# 280889   2017-05-31
# Name: visit_date, Length: 393, dtype: datetime64[ns]
# 126485   2016-07-01
# 126486   2016-07-02
# 126487   2016-07-03
# 126488   2016-07-04
# 126489   2016-07-05
#             ...
# 265051   2017-05-27
# 265052   2017-05-28
# 265053   2017-05-29
# 265054   2017-05-30
# 265055   2017-05-31
# Name: visit_date, Length: 281, dtype: datetime64[ns]
# 126727   2016-07-01
# 126728   2016-07-02
# 126729   2016-07-04
# 126730   2016-07-05
# 126731   2016-07-06
#             ...
# 278896   2017-05-27
# 278897   2017-05-28
# 278898   2017-05-29
# 278899   2017-05-30
# 278900   2017-05-31
# Name: visit_date, Length: 318, dtype: datetime64[ns]
# 127006   2016-07-01
# 127007   2016-07-02
# 127008   2016-07-03
# 127009   2016-07-04
# 127010   2016-07-06
#             ...
# 280027   2017-05-27
# 280028   2017-05-28
# 280029   2017-05-29
# 280030   2017-05-30
# 280031   2017-05-31
# Name: visit_date, Length: 321, dtype: datetime64[ns]
# 127288   2016-07-01
# 127289   2016-07-02
# 127290   2016-07-04
# 127291   2016-07-05
# 127292   2016-07-06
#             ...
# 255496   2017-05-27
# 255497   2017-05-28
# 255498   2017-05-29
# 255499   2017-05-30
# 255500   2017-05-31
# Name: visit_date, Length: 292, dtype: datetime64[ns]
# 127541   2016-01-05
# 127542   2016-01-06
# 127543   2016-01-07
# 127544   2016-01-08
# 127545   2016-01-09
#             ...
# 274333   2017-05-27
# 274334   2017-05-28
# 274335   2017-05-29
# 274336   2017-05-30
# 274337   2017-05-31
# Name: visit_date, Length: 438, dtype: datetime64[ns]
# 127940   2016-07-01
# 127941   2016-07-02
# 127942   2016-07-03
# 127943   2016-07-04
# 127944   2016-07-05
#             ...
# 257485   2017-05-27
# 257486   2017-05-28
# 257487   2017-05-29
# 257488   2017-05-30
# 257489   2017-05-31
# Name: visit_date, Length: 293, dtype: datetime64[ns]
# 128194   2016-07-01
# 128195   2016-07-02
# 128196   2016-07-03
# 128197   2016-07-04
# 128198   2016-07-05
#             ...
# 281899   2017-05-27
# 281900   2017-05-28
# 281901   2017-05-29
# 281902   2017-05-30
# 281903   2017-05-31
# Name: visit_date, Length: 321, dtype: datetime64[ns]
# 128476   2016-07-01
# 128477   2016-07-02
# 128478   2016-07-03
# 128479   2016-07-04
# 128480   2016-07-06
#             ...
# 278974   2017-05-27
# 278975   2017-05-28
# 278976   2017-05-29
# 278977   2017-05-30
# 278978   2017-05-31
# Name: visit_date, Length: 283, dtype: datetime64[ns]
# 128720   2016-01-05
# 128721   2016-01-06
# 128722   2016-01-07
# 128723   2016-01-08
# 128724   2016-01-09
#             ...
# 264466   2017-05-27
# 264467   2017-05-28
# 264468   2017-05-29
# 264469   2017-05-30
# 264470   2017-05-31
# Name: visit_date, Length: 447, dtype: datetime64[ns]
# 129128   2016-01-05
# 129129   2016-01-06
# 129130   2016-01-07
# 129131   2016-01-08
# 129132   2016-01-09
#             ...
# 263101   2017-05-27
# 263102   2017-05-28
# 263103   2017-05-29
# 263104   2017-05-30
# 263105   2017-05-31
# Name: visit_date, Length: 370, dtype: datetime64[ns]
# 129459   2016-01-08
# 129460   2016-01-09
# 129461   2016-01-10
# 129462   2016-01-12
# 129463   2016-01-13
#             ...
# 256276   2017-05-27
# 256277   2017-05-28
# 256278   2017-05-29
# 256279   2017-05-30
# 256280   2017-05-31
# Name: visit_date, Length: 415, dtype: datetime64[ns]
# 129835   2016-07-01
# 129836   2016-07-02
# 129837   2016-07-04
# 129838   2016-07-05
# 129839   2016-07-06
#             ...
# 257329   2017-05-27
# 257330   2017-05-28
# 257331   2017-05-29
# 257332   2017-05-30
# 257333   2017-05-31
# Name: visit_date, Length: 274, dtype: datetime64[ns]
# 130070   2016-07-01
# 130071   2016-07-02
# 130072   2016-07-03
# 130073   2016-07-04
# 130074   2016-07-07
#             ...
# 270745   2017-05-27
# 270746   2017-05-28
# 270747   2017-05-29
# 270748   2017-05-30
# 270749   2017-05-31
# Name: visit_date, Length: 261, dtype: datetime64[ns]
# 130292   2016-07-01
# 130293   2016-07-02
# 130294   2016-07-03
# 130295   2016-07-04
# 130296   2016-07-05
#             ...
# 252883   2017-05-27
# 252884   2017-05-28
# 252885   2017-05-29
# 252886   2017-05-30
# 252887   2017-05-31
# Name: visit_date, Length: 333, dtype: datetime64[ns]
# 130586   2016-01-04
# 130587   2016-01-05
# 130588   2016-01-06
# 130589   2016-01-07
# 130590   2016-01-08
#             ...
# 265519   2017-05-27
# 265520   2017-05-28
# 265521   2017-05-29
# 265522   2017-05-30
# 265523   2017-05-31
# Name: visit_date, Length: 500, dtype: datetime64[ns]
# 131047   2016-01-05
# 131048   2016-01-06
# 131049   2016-01-07
# 131050   2016-01-08
# 131051   2016-01-09
#             ...
# 252766   2017-05-27
# 252767   2017-05-28
# 252768   2017-05-29
# 252769   2017-05-30
# 252770   2017-05-31
# Name: visit_date, Length: 440, dtype: datetime64[ns]
# 131448   2016-07-01
# 131449   2016-07-02
# 131450   2016-07-03
# 131451   2016-07-04
# 131452   2016-07-06
#             ...
# 258889   2017-05-27
# 258890   2017-05-28
# 258891   2017-05-29
# 258892   2017-05-30
# 258893   2017-05-31
# Name: visit_date, Length: 305, dtype: datetime64[ns]
# 131714   2016-07-01
# 131715   2016-07-02
# 131716   2016-07-04
# 131717   2016-07-05
# 131718   2016-07-06
#             ...
# 265558   2017-05-27
# 265559   2017-05-28
# 265560   2017-05-29
# 265561   2017-05-30
# 265562   2017-05-31
# Name: visit_date, Length: 283, dtype: datetime64[ns]
# 131958   2016-01-01
# 131959   2016-01-02
# 131960   2016-01-03
# 131961   2016-01-04
# 131962   2016-01-05
#             ...
# 281509   2017-05-27
# 281510   2017-05-28
# 281511   2017-05-29
# 281512   2017-05-30
# 281513   2017-05-31
# Name: visit_date, Length: 458, dtype: datetime64[ns]
# 132377   2016-07-01
# 132378   2016-07-02
# 132379   2016-07-03
# 132380   2016-07-04
# 132381   2016-07-06
#             ...
# 278272   2017-05-27
# 278273   2017-05-28
# 278274   2017-05-29
# 278275   2017-05-30
# 278276   2017-05-31
# Name: visit_date, Length: 265, dtype: datetime64[ns]
# 132603   2016-07-01
# 132604   2016-07-02
# 132605   2016-07-03
# 132606   2016-07-04
# 132607   2016-07-05
#             ...
# 259513   2017-05-27
# 259514   2017-05-28
# 259515   2017-05-29
# 259516   2017-05-30
# 259517   2017-05-31
# Name: visit_date, Length: 288, dtype: datetime64[ns]
# 132852   2016-01-07
# 132853   2016-01-08
# 132854   2016-01-09
# 132855   2016-01-10
# 132856   2016-01-11
#             ...
# 273865   2017-05-27
# 273866   2017-05-28
# 273867   2017-05-29
# 273868   2017-05-30
# 273869   2017-05-31
# Name: visit_date, Length: 486, dtype: datetime64[ns]
# 133299   2016-07-01
# 133300   2016-07-02
# 133301   2016-07-04
# 133302   2016-07-05
# 133303   2016-07-06
#             ...
# 269029   2017-05-27
# 269030   2017-05-28
# 269031   2017-05-29
# 269032   2017-05-30
# 269033   2017-05-31
# Name: visit_date, Length: 261, dtype: datetime64[ns]
# 133521   2016-07-01
# 133522   2016-07-02
# 133523   2016-07-03
# 133524   2016-07-04
# 133525   2016-07-05
#             ...
# 272734   2017-05-27
# 272735   2017-05-28
# 272736   2017-05-29
# 272737   2017-05-30
# 272738   2017-05-31
# Name: visit_date, Length: 285, dtype: datetime64[ns]
# 133767   2016-01-05
# 133768   2016-01-06
# 133769   2016-01-09
# 133770   2016-01-10
# 133771   2016-01-11
#             ...
# 252844   2017-05-27
# 252845   2017-05-28
# 252846   2017-05-29
# 252847   2017-05-30
# 252848   2017-05-31
# Name: visit_date, Length: 368, dtype: datetime64[ns]
# 134096   2016-01-05
# 134097   2016-01-06
# 134098   2016-01-07
# 134099   2016-01-08
# 134100   2016-01-09
#             ...
# 282211   2017-05-27
# 282212   2017-05-28
# 282213   2017-05-29
# 282214   2017-05-30
# 282215   2017-05-31
# Name: visit_date, Length: 460, dtype: datetime64[ns]
# 134517   2016-01-04
# 134518   2016-01-05
# 134519   2016-01-06
# 134520   2016-01-07
# 134521   2016-01-08
#             ...
# 263296   2017-05-27
# 263297   2017-05-28
# 263298   2017-05-29
# 263299   2017-05-30
# 263300   2017-05-31
# Name: visit_date, Length: 454, dtype: datetime64[ns]
# 134932   2016-07-01
# 134933   2016-07-02
# 134934   2016-07-03
# 134935   2016-07-04
# 134936   2016-07-05
#             ...
# 275815   2017-05-27
# 275816   2017-05-28
# 275817   2017-05-29
# 275818   2017-05-30
# 275819   2017-05-31
# Name: visit_date, Length: 334, dtype: datetime64[ns]
# 135227   2016-07-01
# 135228   2016-07-02
# 135229   2016-07-04
# 135230   2016-07-05
# 135231   2016-07-06
#             ...
# 272188   2017-05-27
# 272189   2017-05-28
# 272190   2017-05-29
# 272191   2017-05-30
# 272192   2017-05-31
# Name: visit_date, Length: 280, dtype: datetime64[ns]
# 135468   2016-07-01
# 135469   2016-07-02
# 135470   2016-07-03
# 135471   2016-07-04
# 135472   2016-07-05
#             ...
# 281587   2017-05-27
# 281588   2017-05-28
# 281589   2017-05-29
# 281590   2017-05-30
# 281591   2017-05-31
# Name: visit_date, Length: 278, dtype: datetime64[ns]
# 135707   2016-07-01
# 135708   2016-07-02
# 135709   2016-07-03
# 135710   2016-07-05
# 135711   2016-07-06
#             ...
# 277843   2017-05-27
# 277844   2017-05-28
# 277845   2017-05-29
# 277846   2017-05-30
# 277847   2017-05-31
# Name: visit_date, Length: 304, dtype: datetime64[ns]
# 135972   2016-07-01
# 135973   2016-07-03
# 135974   2016-07-05
# 135975   2016-07-06
# 135976   2016-07-07
#             ...
# 274879   2017-05-27
# 274880   2017-05-28
# 274881   2017-05-29
# 274882   2017-05-30
# 274883   2017-05-31
# Name: visit_date, Length: 281, dtype: datetime64[ns]
# 136214   2016-01-05
# 136215   2016-01-06
# 136216   2016-01-07
# 136217   2016-01-08
# 136218   2016-01-09
#             ...
# 259630   2017-05-27
# 259631   2017-05-28
# 259632   2017-05-29
# 259633   2017-05-30
# 259634   2017-05-31
# Name: visit_date, Length: 436, dtype: datetime64[ns]
# 136611   2016-07-01
# 136612   2016-07-02
# 136613   2016-07-03
# 136614   2016-07-05
# 136615   2016-07-06
#             ...
# 256822   2017-05-27
# 256823   2017-05-28
# 256824   2017-05-29
# 256825   2017-05-30
# 256826   2017-05-31
# Name: visit_date, Length: 292, dtype: datetime64[ns]
# 136864   2016-07-01
# 136865   2016-07-02
# 136866   2016-07-04
# 136867   2016-07-05
# 136868   2016-07-06
#             ...
# 281236   2017-05-27
# 281237   2017-05-28
# 281238   2017-05-29
# 281239   2017-05-30
# 281240   2017-05-31
# Name: visit_date, Length: 277, dtype: datetime64[ns]
# 137102   2016-07-01
# 137103   2016-07-02
# 137104   2016-07-03
# 137105   2016-07-05
# 137106   2016-07-06
#             ...
# 273982   2017-05-27
# 273983   2017-05-28
# 273984   2017-05-29
# 273985   2017-05-30
# 273986   2017-05-31
# Name: visit_date, Length: 262, dtype: datetime64[ns]
# 137325   2016-07-01
# 137326   2016-07-02
# 137327   2016-07-03
# 137328   2016-07-04
# 137329   2016-07-05
#             ...
# 271993   2017-05-27
# 271994   2017-05-28
# 271995   2017-05-29
# 271996   2017-05-30
# 271997   2017-05-31
# Name: visit_date, Length: 318, dtype: datetime64[ns]
# 137604   2016-07-01
# 137605   2016-07-02
# 137606   2016-07-04
# 137607   2016-07-05
# 137608   2016-07-07
#             ...
# 282523   2017-05-27
# 282524   2017-05-28
# 282525   2017-05-29
# 282526   2017-05-30
# 282527   2017-05-31
# Name: visit_date, Length: 306, dtype: datetime64[ns]
# 137871   2016-07-01
# 137872   2016-07-02
# 137873   2016-07-03
# 137874   2016-07-05
# 137875   2016-07-07
#             ...
# 276166   2017-05-27
# 276167   2017-05-28
# 276168   2017-05-29
# 276169   2017-05-30
# 276170   2017-05-31
# Name: visit_date, Length: 265, dtype: datetime64[ns]
# 138097   2016-07-01
# 138098   2016-07-02
# 138099   2016-07-03
# 138100   2016-07-04
# 138101   2016-07-05
#             ...
# 260254   2017-05-27
# 260255   2017-05-28
# 260256   2017-05-29
# 260257   2017-05-30
# 260258   2017-05-31
# Name: visit_date, Length: 288, dtype: datetime64[ns]
# 138346   2016-01-04
# 138347   2016-01-05
# 138348   2016-01-06
# 138349   2016-01-07
# 138350   2016-01-08
#             ...
# 254248   2017-05-27
# 254249   2017-05-28
# 254250   2017-05-29
# 254251   2017-05-30
# 254252   2017-05-31
# Name: visit_date, Length: 232, dtype: datetime64[ns]
# 138539   2016-07-01
# 138540   2016-07-02
# 138541   2016-07-03
# 138542   2016-07-04
# 138543   2016-07-05
#             ...
# 267508   2017-05-27
# 267509   2017-05-28
# 267510   2017-05-29
# 267511   2017-05-30
# 267512   2017-05-31
# Name: visit_date, Length: 325, dtype: datetime64[ns]
# 138825   2016-01-06
# 138826   2016-01-07
# 138827   2016-01-08
# 138828   2016-01-09
# 138829   2016-01-10
#             ...
# 265246   2017-05-27
# 265247   2017-05-28
# 265248   2017-05-29
# 265249   2017-05-30
# 265250   2017-05-31
# Name: visit_date, Length: 419, dtype: datetime64[ns]
# 139205   2016-01-05
# 139206   2016-01-06
# 139207   2016-01-07
# 139208   2016-01-08
# 139209   2016-01-09
#             ...
# 254911   2017-05-27
# 254912   2017-05-28
# 254913   2017-05-29
# 254914   2017-05-30
# 254915   2017-05-31
# Name: visit_date, Length: 499, dtype: datetime64[ns]
# 139665   2016-01-01
# 139666   2016-01-02
# 139667   2016-01-03
# 139668   2016-01-04
# 139669   2016-01-05
#             ...
# 256627   2017-05-27
# 256628   2017-05-28
# 256629   2017-05-29
# 256630   2017-05-30
# 256631   2017-05-31
# Name: visit_date, Length: 481, dtype: datetime64[ns]
# 140107   2016-01-09
# 140108   2016-01-10
# 140109   2016-01-11
# 140110   2016-01-13
# 140111   2016-01-14
#             ...
# 265714   2017-05-27
# 265715   2017-05-28
# 265716   2017-05-29
# 265717   2017-05-30
# 265718   2017-05-31
# Name: visit_date, Length: 369, dtype: datetime64[ns]
# 140437   2016-07-01
# 140438   2016-07-02
# 140439   2016-07-03
# 140440   2016-07-04
# 140441   2016-07-05
#             ...
# 266572   2017-05-27
# 266573   2017-05-28
# 266574   2017-05-29
# 266575   2017-05-30
# 266576   2017-05-31
# Name: visit_date, Length: 297, dtype: datetime64[ns]
# 140695   2016-01-04
# 140696   2016-01-05
# 140697   2016-01-06
# 140698   2016-01-07
# 140699   2016-01-08
#             ...
# 270004   2017-05-27
# 270005   2017-05-28
# 270006   2017-05-29
# 270007   2017-05-30
# 270008   2017-05-31
# Name: visit_date, Length: 417, dtype: datetime64[ns]
# 141073   2016-07-01
# 141074   2016-07-02
# 141075   2016-07-03
# 141076   2016-07-04
# 141077   2016-07-05
#             ...
# 257368   2017-05-27
# 257369   2017-05-28
# 257370   2017-05-29
# 257371   2017-05-30
# 257372   2017-05-31
# Name: visit_date, Length: 329, dtype: datetime64[ns]
# 141363   2016-01-04
# 141364   2016-01-05
# 141365   2016-01-06
# 141366   2016-01-07
# 141367   2016-01-08
#             ...
# 252922   2017-05-27
# 252923   2017-05-28
# 252924   2017-05-29
# 252925   2017-05-30
# 252926   2017-05-31
# Name: visit_date, Length: 419, dtype: datetime64[ns]
# 141743   2016-01-04
# 141744   2016-01-05
# 141745   2016-01-06
# 141746   2016-01-07
# 141747   2016-01-08
#             ...
# 282991   2017-05-27
# 282992   2017-05-28
# 282993   2017-05-29
# 282994   2017-05-30
# 282995   2017-05-31
# Name: visit_date, Length: 509, dtype: datetime64[ns]
# 142213   2016-01-01
# 142214   2016-01-02
# 142215   2016-01-03
# 142216   2016-01-08
# 142217   2016-01-09
#             ...
# 266962   2017-05-27
# 266963   2017-05-28
# 266964   2017-05-29
# 266965   2017-05-30
# 266966   2017-05-31
# Name: visit_date, Length: 452, dtype: datetime64[ns]
# 142626   2016-07-01
# 142627   2016-07-02
# 142628   2016-07-03
# 142629   2016-07-04
# 142630   2016-07-05
#             ...
# 259357   2017-05-27
# 259358   2017-05-28
# 259359   2017-05-29
# 259360   2017-05-30
# 259361   2017-05-31
# Name: visit_date, Length: 311, dtype: datetime64[ns]
# 142898   2016-07-01
# 142899   2016-07-02
# 142900   2016-07-05
# 142901   2016-07-06
# 142902   2016-07-07
#             ...
# 260293   2017-05-27
# 260294   2017-05-28
# 260295   2017-05-29
# 260296   2017-05-30
# 260297   2017-05-31
# Name: visit_date, Length: 261, dtype: datetime64[ns]
# 143120   2016-07-01
# 143121   2016-07-02
# 143122   2016-07-03
# 143123   2016-07-04
# 143124   2016-07-06
#             ...
# 252649   2017-05-27
# 252650   2017-05-28
# 252651   2017-05-29
# 252652   2017-05-30
# 252653   2017-05-31
# Name: visit_date, Length: 326, dtype: datetime64[ns]
# 143407   2016-01-05
# 143408   2016-01-06
# 143409   2016-01-07
# 143410   2016-01-08
# 143411   2016-01-09
#             ...
# 261190   2017-05-27
# 261191   2017-05-28
# 261192   2017-05-29
# 261193   2017-05-30
# 261194   2017-05-31
# Name: visit_date, Length: 508, dtype: datetime64[ns]
# 143876   2016-01-04
# 143877   2016-01-05
# 143878   2016-01-06
# 143879   2016-01-07
# 143880   2016-01-08
#             ...
# 259864   2017-05-27
# 259865   2017-05-28
# 259866   2017-05-29
# 259867   2017-05-30
# 259868   2017-05-31
# Name: visit_date, Length: 414, dtype: datetime64[ns]
# 144251   2016-07-01
# 144252   2016-07-02
# 144253   2016-07-03
# 144254   2016-07-04
# 144255   2016-07-06
#             ...
# 257407   2017-05-27
# 257408   2017-05-28
# 257409   2017-05-29
# 257410   2017-05-30
# 257411   2017-05-31
# Name: visit_date, Length: 282, dtype: datetime64[ns]
# 144494   2016-07-01
# 144495   2016-07-02
# 144496   2016-07-03
# 144497   2016-07-04
# 144498   2016-07-05
#             ...
# 260176   2017-05-27
# 260177   2017-05-28
# 260178   2017-05-29
# 260179   2017-05-30
# 260180   2017-05-31
# Name: visit_date, Length: 331, dtype: datetime64[ns]
# 144786   2016-07-01
# 144787   2016-07-02
# 144788   2016-07-03
# 144789   2016-07-04
# 144790   2016-07-06
#             ...
# 272305   2017-05-27
# 272306   2017-05-28
# 272307   2017-05-29
# 272308   2017-05-30
# 272309   2017-05-31
# Name: visit_date, Length: 256, dtype: datetime64[ns]
# 145003   2016-01-05
# 145004   2016-01-06
# 145005   2016-01-07
# 145006   2016-01-08
# 145007   2016-01-09
#             ...
# 264310   2017-05-27
# 264311   2017-05-28
# 264312   2017-05-29
# 264313   2017-05-30
# 264314   2017-05-31
# Name: visit_date, Length: 426, dtype: datetime64[ns]
# 145390   2016-07-01
# 145391   2016-07-02
# 145392   2016-07-03
# 145393   2016-07-04
# 145394   2016-07-05
#             ...
# 277219   2017-05-27
# 277220   2017-05-28
# 277221   2017-05-29
# 277222   2017-05-30
# 277223   2017-05-31
# Name: visit_date, Length: 280, dtype: datetime64[ns]
# 145631   2016-01-02
# 145632   2016-01-03
# 145633   2016-01-04
# 145634   2016-01-05
# 145635   2016-01-07
#             ...
# 276478   2017-05-27
# 276479   2017-05-28
# 276480   2017-05-29
# 276481   2017-05-30
# 276482   2017-05-31
# Name: visit_date, Length: 493, dtype: datetime64[ns]
# 146085   2016-07-01
# 146086   2016-07-02
# 146087   2016-07-04
# 146088   2016-07-05
# 146089   2016-07-06
#             ...
# 270979   2017-05-27
# 270980   2017-05-28
# 270981   2017-05-29
# 270982   2017-05-30
# 270983   2017-05-31
# Name: visit_date, Length: 270, dtype: datetime64[ns]
# 146316   2016-07-01
# 146317   2016-07-02
# 146318   2016-07-05
# 146319   2016-07-06
# 146320   2016-07-07
#             ...
# 268522   2017-05-27
# 268523   2017-05-28
# 268524   2017-05-29
# 268525   2017-05-30
# 268526   2017-05-31
# Name: visit_date, Length: 304, dtype: datetime64[ns]
# 146581   2016-07-01
# 146582   2016-07-02
# 146583   2016-07-03
# 146584   2016-07-04
# 146585   2016-07-05
#             ...
# 253234   2017-05-27
# 253235   2017-05-28
# 253236   2017-05-29
# 253237   2017-05-30
# 253238   2017-05-31
# Name: visit_date, Length: 279, dtype: datetime64[ns]
# 146821   2016-07-01
# 146822   2016-07-02
# 146823   2016-07-03
# 146824   2016-07-04
# 146825   2016-07-07
#             ...
# 274060   2017-05-27
# 274061   2017-05-28
# 274062   2017-05-29
# 274063   2017-05-30
# 274064   2017-05-31
# Name: visit_date, Length: 256, dtype: datetime64[ns]
# 147038   2016-07-01
# 147039   2016-07-02
# 147040   2016-07-04
# 147041   2016-07-05
# 147042   2016-07-06
#             ...
# 277726   2017-05-27
# 277727   2017-05-28
# 277728   2017-05-29
# 277729   2017-05-30
# 277730   2017-05-31
# Name: visit_date, Length: 279, dtype: datetime64[ns]
# 147278   2016-01-04
# 147279   2016-01-05
# 147280   2016-01-06
# 147281   2016-01-07
# 147282   2016-01-08
#             ...
# 261775   2017-05-27
# 261776   2017-05-28
# 261777   2017-05-29
# 261778   2017-05-30
# 261779   2017-05-31
# Name: visit_date, Length: 409, dtype: datetime64[ns]
# 147648   2016-07-01
# 147649   2016-07-02
# 147650   2016-07-03
# 147651   2016-07-04
# 147652   2016-07-05
#             ...
# 280690   2017-05-27
# 280691   2017-05-28
# 280692   2017-05-29
# 280693   2017-05-30
# 280694   2017-05-31
# Name: visit_date, Length: 162, dtype: datetime64[ns]
# 147771   2016-07-01
# 147772   2016-07-02
# 147773   2016-07-03
# 147774   2016-07-04
# 147775   2016-07-05
#             ...
# 283537   2017-05-27
# 283538   2017-05-28
# 283539   2017-05-29
# 283540   2017-05-30
# 283541   2017-05-31
# Name: visit_date, Length: 173, dtype: datetime64[ns]
# 147905   2016-07-01
# 147906   2016-07-04
# 147907   2016-07-05
# 147908   2016-07-06
# 147909   2016-07-07
#             ...
# 261424   2017-05-27
# 261425   2017-05-28
# 261426   2017-05-29
# 261427   2017-05-30
# 261428   2017-05-31
# Name: visit_date, Length: 267, dtype: datetime64[ns]
# 148133   2016-07-01
# 148134   2016-07-02
# 148135   2016-07-03
# 148136   2016-07-05
# 148137   2016-07-06
#             ...
# 148207   2016-09-28
# 148208   2016-09-29
# 148209   2016-09-30
# 148210   2016-10-01
# 148211   2016-10-02
# Name: visit_date, Length: 79, dtype: datetime64[ns]
# 148212   2016-07-01
# 148213   2016-07-02
# 148214   2016-07-03
# 148215   2016-07-04
# 148216   2016-07-05
#             ...
# 267157   2017-05-27
# 267158   2017-05-28
# 267159   2017-05-29
# 267160   2017-05-30
# 267161   2017-05-31
# Name: visit_date, Length: 326, dtype: datetime64[ns]
# 148499   2016-07-02
# 148500   2016-07-04
# 148501   2016-07-07
# 148502   2016-07-08
# 148503   2016-07-11
#             ...
# 148632   2017-02-28
# 148633   2017-03-03
# 148634   2017-03-06
# 148635   2017-03-07
# 148636   2017-03-08
# Name: visit_date, Length: 138, dtype: datetime64[ns]
# 148637   2016-01-01
# 148638   2016-01-02
# 148639   2016-01-03
# 148640   2016-01-04
# 148641   2016-01-05
#             ...
# 277531   2017-05-27
# 277532   2017-05-28
# 277533   2017-05-29
# 277534   2017-05-30
# 277535   2017-05-31
# Name: visit_date, Length: 496, dtype: datetime64[ns]
# 149094   2016-01-05
# 149095   2016-01-06
# 149096   2016-01-07
# 149097   2016-01-08
# 149098   2016-01-09
#             ...
# 281470   2017-05-27
# 281471   2017-05-28
# 281472   2017-05-29
# 281473   2017-05-30
# 281474   2017-05-31
# Name: visit_date, Length: 410, dtype: datetime64[ns]
# 149465   2016-01-04
# 149466   2016-01-05
# 149467   2016-01-06
# 149468   2016-01-07
# 149469   2016-01-09
#             ...
# 257602   2017-05-27
# 257603   2017-05-28
# 257604   2017-05-29
# 257605   2017-05-30
# 257606   2017-05-31
# Name: visit_date, Length: 318, dtype: datetime64[ns]
# 149744   2016-07-01
# 149745   2016-07-02
# 149746   2016-07-03
# 149747   2016-07-04
# 149748   2016-07-05
#             ...
# 265792   2017-05-27
# 265793   2017-05-28
# 265794   2017-05-29
# 265795   2017-05-30
# 265796   2017-05-31
# Name: visit_date, Length: 213, dtype: datetime64[ns]
# 149918   2016-01-04
# 149919   2016-01-05
# 149920   2016-01-06
# 149921   2016-01-07
# 149922   2016-01-08
#             ...
# 266923   2017-05-27
# 266924   2017-05-28
# 266925   2017-05-29
# 266926   2017-05-30
# 266927   2017-05-31
# Name: visit_date, Length: 494, dtype: datetime64[ns]
# 150373   2016-07-01
# 150374   2016-07-02
# 150375   2016-07-03
# 150376   2016-07-04
# 150377   2016-07-05
#             ...
# 255769   2017-05-27
# 255770   2017-05-28
# 255771   2017-05-29
# 255772   2017-05-30
# 255773   2017-05-31
# Name: visit_date, Length: 323, dtype: datetime64[ns]
# 150657   2016-07-01
# 150658   2016-07-02
# 150659   2016-07-03
# 150660   2016-07-04
# 150661   2016-07-05
#             ...
# 282913   2017-05-27
# 282914   2017-05-28
# 282915   2017-05-29
# 282916   2017-05-30
# 282917   2017-05-31
# Name: visit_date, Length: 326, dtype: datetime64[ns]
# 150944   2016-07-01
# 150945   2016-07-02
# 150946   2016-07-03
# 150947   2016-07-04
# 150948   2016-07-05
#             ...
# 258070   2017-05-27
# 258071   2017-05-28
# 258072   2017-05-29
# 258073   2017-05-30
# 258074   2017-05-31
# Name: visit_date, Length: 332, dtype: datetime64[ns]
# 151237   2016-01-06
# 151238   2016-01-07
# 151239   2016-01-08
# 151240   2016-01-09
# 151241   2016-01-10
#             ...
# 151453   2016-11-02
# 151454   2016-11-03
# 151455   2016-11-04
# 151456   2016-11-05
# 151457   2016-11-06
# Name: visit_date, Length: 221, dtype: datetime64[ns]
# 151458   2016-07-01
# 151459   2016-07-03
# 151460   2016-07-04
# 151461   2016-07-05
# 151462   2016-07-06
#             ...
# 268483   2017-05-27
# 268484   2017-05-28
# 268485   2017-05-29
# 268486   2017-05-30
# 268487   2017-05-31
# Name: visit_date, Length: 305, dtype: datetime64[ns]
# 151724   2016-01-02
# 151725   2016-01-03
# 151726   2016-01-04
# 151727   2016-01-05
# 151728   2016-01-06
#             ...
# 281431   2017-05-27
# 281432   2017-05-28
# 281433   2017-05-29
# 281434   2017-05-30
# 281435   2017-05-31
# Name: visit_date, Length: 462, dtype: datetime64[ns]
# 152147   2017-01-24
# 152148   2017-02-01
# 152149   2017-02-02
# 152150   2017-02-03
# 152151   2017-02-04
#             ...
# 267703   2017-05-27
# 267704   2017-05-28
# 267705   2017-05-29
# 267706   2017-05-30
# 267707   2017-05-31
# Name: visit_date, Length: 108, dtype: datetime64[ns]
# 152216   2017-01-30
# 152217   2017-01-31
# 152218   2017-02-01
# 152219   2017-02-02
# 152220   2017-02-03
#             ...
# 256549   2017-05-27
# 256550   2017-05-28
# 256551   2017-05-29
# 256552   2017-05-30
# 256553   2017-05-31
# Name: visit_date, Length: 122, dtype: datetime64[ns]
# 152299   2016-07-01
# 152300   2016-07-02
# 152301   2016-07-03
# 152302   2016-07-05
# 152303   2016-07-06
#             ...
# 258031   2017-05-27
# 258032   2017-05-28
# 258033   2017-05-29
# 258034   2017-05-30
# 258035   2017-05-31
# Name: visit_date, Length: 284, dtype: datetime64[ns]
# 152544   2016-01-06
# 152545   2016-01-07
# 152546   2016-01-09
# 152547   2016-01-10
# 152548   2016-01-12
#             ...
# 282406   2017-05-27
# 282407   2017-05-28
# 282408   2017-05-29
# 282409   2017-05-30
# 282410   2017-05-31
# Name: visit_date, Length: 442, dtype: datetime64[ns]
# 152947   2016-01-02
# 152948   2016-01-03
# 152949   2016-01-04
# 152950   2016-01-05
# 152951   2016-01-06
#             ...
# 263920   2017-05-27
# 263921   2017-05-28
# 263922   2017-05-29
# 263923   2017-05-30
# 263924   2017-05-31
# Name: visit_date, Length: 495, dtype: datetime64[ns]
# 153403   2016-01-01
# 153404   2016-01-02
# 153405   2016-01-03
# 153406   2016-01-04
# 153407   2016-01-07
#             ...
# 267235   2017-05-27
# 267236   2017-05-28
# 267237   2017-05-29
# 267238   2017-05-30
# 267239   2017-05-31
# Name: visit_date, Length: 358, dtype: datetime64[ns]
# 153722   2016-01-04
# 153723   2016-01-05
# 153724   2016-01-06
# 153725   2016-01-07
# 153726   2016-01-08
#             ...
# 257251   2017-05-27
# 257252   2017-05-28
# 257253   2017-05-29
# 257254   2017-05-30
# 257255   2017-05-31
# Name: visit_date, Length: 446, dtype: datetime64[ns]
# 154129   2016-07-01
# 154130   2016-07-02
# 154131   2016-07-03
# 154132   2016-07-04
# 154133   2016-07-05
#             ...
# 256432   2017-05-27
# 256433   2017-05-28
# 256434   2017-05-29
# 256435   2017-05-30
# 256436   2017-05-31
# Name: visit_date, Length: 334, dtype: datetime64[ns]
# 154424   2016-07-01
# 154425   2016-07-02
# 154426   2016-07-03
# 154427   2016-07-04
# 154428   2016-07-05
#             ...
# 270901   2017-05-27
# 270902   2017-05-28
# 270903   2017-05-29
# 270904   2017-05-30
# 270905   2017-05-31
# Name: visit_date, Length: 312, dtype: datetime64[ns]
# 154697   2016-07-01
# 154698   2016-07-02
# 154699   2016-07-03
# 154700   2016-07-04
# 154701   2016-07-05
#             ...
# 262087   2017-05-27
# 262088   2017-05-28
# 262089   2017-05-29
# 262090   2017-05-30
# 262091   2017-05-31
# Name: visit_date, Length: 314, dtype: datetime64[ns]
# 154972   2016-07-01
# 154973   2016-07-02
# 154974   2016-07-03
# 154975   2016-07-04
# 154976   2016-07-05
#             ...
# 269653   2017-05-27
# 269654   2017-05-28
# 269655   2017-05-29
# 269656   2017-05-30
# 269657   2017-05-31
# Name: visit_date, Length: 332, dtype: datetime64[ns]
# 155265   2016-07-05
# 155266   2016-07-06
# 155267   2016-07-07
# 155268   2016-07-08
# 155269   2016-07-09
#             ...
# 264115   2017-05-27
# 264116   2017-05-28
# 264117   2017-05-29
# 264118   2017-05-30
# 264119   2017-05-31
# Name: visit_date, Length: 263, dtype: datetime64[ns]
# 155489   2016-07-01
# 155490   2016-07-02
# 155491   2016-07-03
# 155492   2016-07-04
# 155493   2016-07-05
#             ...
# 257836   2017-05-27
# 257837   2017-05-28
# 257838   2017-05-29
# 257839   2017-05-30
# 257840   2017-05-31
# Name: visit_date, Length: 333, dtype: datetime64[ns]
# 155783   2016-07-01
# 155784   2016-07-02
# 155785   2016-07-03
# 155786   2016-07-04
# 155787   2016-07-05
#             ...
# 281353   2017-05-27
# 281354   2017-05-28
# 281355   2017-05-29
# 281356   2017-05-30
# 281357   2017-05-31
# Name: visit_date, Length: 294, dtype: datetime64[ns]
# 156038   2016-01-02
# 156039   2016-01-03
# 156040   2016-01-04
# 156041   2016-01-05
# 156042   2016-01-06
#             ...
# 267274   2017-05-27
# 267275   2017-05-28
# 267276   2017-05-29
# 267277   2017-05-30
# 267278   2017-05-31
# Name: visit_date, Length: 510, dtype: datetime64[ns]
# 156509   2016-01-03
# 156510   2016-01-05
# 156511   2016-01-07
# 156512   2016-01-08
# 156513   2016-01-09
#             ...
# 260488   2017-05-27
# 260489   2017-05-28
# 260490   2017-05-29
# 260491   2017-05-30
# 260492   2017-05-31
# Name: visit_date, Length: 479, dtype: datetime64[ns]
# 156949   2016-11-25
# 156950   2016-11-26
# 156951   2016-11-27
# 156952   2016-11-28
# 156953   2016-11-29
#             ...
# 280183   2017-05-27
# 280184   2017-05-28
# 280185   2017-05-29
# 280186   2017-05-30
# 280187   2017-05-31
# Name: visit_date, Length: 188, dtype: datetime64[ns]
# 157098   2016-01-04
# 157099   2016-01-05
# 157100   2016-01-06
# 157101   2016-01-07
# 157102   2016-01-08
#             ...
# 282172   2017-05-27
# 282173   2017-05-28
# 282174   2017-05-29
# 282175   2017-05-30
# 282176   2017-05-31
# Name: visit_date, Length: 499, dtype: datetime64[ns]
# 157558   2016-07-01
# 157559   2016-07-02
# 157560   2016-07-03
# 157561   2016-07-04
# 157562   2016-07-06
#             ...
# 272929   2017-05-27
# 272930   2017-05-28
# 272931   2017-05-29
# 272932   2017-05-30
# 272933   2017-05-31
# Name: visit_date, Length: 301, dtype: datetime64[ns]
# 157820   2016-07-06
# 157821   2016-08-24
# 157822   2017-03-15
# 157823   2017-03-16
# 157824   2017-03-17
#             ...
# 266806   2017-05-27
# 266807   2017-05-28
# 266808   2017-05-29
# 266809   2017-05-30
# 266810   2017-05-31
# Name: visit_date, Length: 80, dtype: datetime64[ns]
# 157861   2016-03-06
# 157862   2016-03-08
# 157863   2016-03-09
# 157864   2016-03-10
# 157865   2016-03-11
#             ...
# 275659   2017-05-27
# 275660   2017-05-28
# 275661   2017-05-29
# 275662   2017-05-30
# 275663   2017-05-31
# Name: visit_date, Length: 364, dtype: datetime64[ns]
# 158186   2017-03-02
# 158187   2017-04-01
# 158188   2017-04-02
# 158189   2017-04-04
# 158190   2017-04-05
# 158191   2017-04-06
# 158192   2017-04-07
# 158193   2017-04-08
# 158194   2017-04-09
# 158195   2017-04-11
# 158196   2017-04-12
# 158197   2017-04-13
# 158198   2017-04-14
# 158199   2017-04-15
# 158200   2017-04-16
# 158201   2017-04-18
# 158202   2017-04-19
# 158203   2017-04-20
# 158204   2017-04-21
# 158205   2017-04-22
# 269658   2017-04-23
# 269659   2017-04-24
# 269660   2017-04-25
# 269661   2017-04-26
# 269662   2017-04-27
# 269663   2017-04-28
# 269664   2017-04-29
# 269665   2017-04-30
# 269666   2017-05-01
# 269667   2017-05-02
# 269668   2017-05-03
# 269669   2017-05-04
# 269670   2017-05-05
# 269671   2017-05-06
# 269672   2017-05-07
# 269673   2017-05-08
# 269674   2017-05-09
# 269675   2017-05-10
# 269676   2017-05-11
# 269677   2017-05-12
# 269678   2017-05-13
# 269679   2017-05-14
# 269680   2017-05-15
# 269681   2017-05-16
# 269682   2017-05-17
# 269683   2017-05-18
# 269684   2017-05-19
# 269685   2017-05-20
# 269686   2017-05-21
# 269687   2017-05-22
# 269688   2017-05-23
# 269689   2017-05-24
# 269690   2017-05-25
# 269691   2017-05-26
# 269692   2017-05-27
# 269693   2017-05-28
# 269694   2017-05-29
# 269695   2017-05-30
# 269696   2017-05-31
# Name: visit_date, dtype: datetime64[ns]
# 158206   2016-01-05
# 158207   2016-01-06
# 158208   2016-01-07
# 158209   2016-01-08
# 158210   2016-01-09
#             ...
# 266728   2017-05-27
# 266729   2017-05-28
# 266730   2017-05-29
# 266731   2017-05-30
# 266732   2017-05-31
# Name: visit_date, Length: 435, dtype: datetime64[ns]
# 158602   2016-01-02
# 158603   2016-01-03
# 158604   2016-01-04
# 158605   2016-01-05
# 158606   2016-01-06
#             ...
# 262711   2017-05-27
# 262712   2017-05-28
# 262713   2017-05-29
# 262714   2017-05-30
# 262715   2017-05-31
# Name: visit_date, Length: 516, dtype: datetime64[ns]
# 159079   2016-07-01
# 159080   2016-07-02
# 159081   2016-07-03
# 159082   2016-07-04
# 159083   2016-07-05
#             ...
# 255028   2017-05-27
# 255029   2017-05-28
# 255030   2017-05-29
# 255031   2017-05-30
# 255032   2017-05-31
# Name: visit_date, Length: 326, dtype: datetime64[ns]
# 159366   2016-01-05
# 159367   2016-01-06
# 159368   2016-01-07
# 159369   2016-01-08
# 159370   2016-01-09
#             ...
# 280846   2017-05-27
# 280847   2017-05-28
# 280848   2017-05-29
# 280849   2017-05-30
# 280850   2017-05-31
# Name: visit_date, Length: 443, dtype: datetime64[ns]
# 159770   2016-07-01
# 159771   2016-07-02
# 159772   2016-07-03
# 159773   2016-07-04
# 159774   2016-07-06
#             ...
# 252298   2017-05-27
# 252299   2017-05-28
# 252300   2017-05-29
# 252301   2017-05-30
# 252302   2017-05-31
# Name: visit_date, Length: 290, dtype: datetime64[ns]
# 160021   2016-07-01
# 160022   2016-07-02
# 160023   2016-07-03
# 160024   2016-07-04
# 160025   2016-07-05
#             ...
# 279715   2017-05-27
# 279716   2017-05-28
# 279717   2017-05-29
# 279718   2017-05-30
# 279719   2017-05-31
# Name: visit_date, Length: 326, dtype: datetime64[ns]
# 160308   2016-07-01
# 160309   2016-07-02
# 160310   2016-07-03
# 160311   2016-07-05
# 160312   2016-07-06
#             ...
# 267586   2017-05-27
# 267587   2017-05-28
# 267588   2017-05-29
# 267589   2017-05-30
# 267590   2017-05-31
# Name: visit_date, Length: 260, dtype: datetime64[ns]
# 160529   2016-01-04
# 160530   2016-01-05
# 160531   2016-01-07
# 160532   2016-01-08
# 160533   2016-01-09
#             ...
# 283303   2017-05-27
# 283304   2017-05-28
# 283305   2017-05-29
# 283306   2017-05-30
# 283307   2017-05-31
# Name: visit_date, Length: 334, dtype: datetime64[ns]
# 160824   2016-07-01
# 160825   2016-07-02
# 160826   2016-07-04
# 160827   2016-07-05
# 160828   2016-07-06
#             ...
# 265831   2017-05-27
# 265832   2017-05-28
# 265833   2017-05-29
# 265834   2017-05-30
# 265835   2017-05-31
# Name: visit_date, Length: 266, dtype: datetime64[ns]
# 161051   2016-07-01
# 161052   2016-07-02
# 161053   2016-07-03
# 161054   2016-07-04
# 161055   2016-07-05
#             ...
# 278701   2017-05-27
# 278702   2017-05-28
# 278703   2017-05-29
# 278704   2017-05-30
# 278705   2017-05-31
# Name: visit_date, Length: 311, dtype: datetime64[ns]
# 161323   2016-07-01
# 161324   2016-07-02
# 161325   2016-07-04
# 161326   2016-07-05
# 161327   2016-07-06
#             ...
# 260644   2017-05-27
# 260645   2017-05-28
# 260646   2017-05-29
# 260647   2017-05-30
# 260648   2017-05-31
# Name: visit_date, Length: 253, dtype: datetime64[ns]
# 161537   2016-01-04
# 161538   2016-01-05
# 161539   2016-01-06
# 161540   2016-01-07
# 161541   2016-01-08
#             ...
# 257173   2017-05-27
# 257174   2017-05-28
# 257175   2017-05-29
# 257176   2017-05-30
# 257177   2017-05-31
# Name: visit_date, Length: 417, dtype: datetime64[ns]
# 161915   2016-01-01
# 161916   2016-01-02
# 161917   2016-01-03
# 161918   2016-01-04
# 161919   2016-01-05
#             ...
# 258772   2017-05-27
# 258773   2017-05-28
# 258774   2017-05-29
# 258775   2017-05-30
# 258776   2017-05-31
# Name: visit_date, Length: 510, dtype: datetime64[ns]
# 162386   2016-01-03
# 162387   2016-01-04
# 162388   2016-01-05
# 162389   2016-01-06
# 162390   2016-01-07
#             ...
# 269731   2017-05-27
# 269732   2017-05-28
# 269733   2017-05-29
# 269734   2017-05-30
# 269735   2017-05-31
# Name: visit_date, Length: 485, dtype: datetime64[ns]
# 162832   2016-01-03
# 162833   2016-01-04
# 162834   2016-01-05
# 162835   2016-01-06
# 162836   2016-01-07
#             ...
# 273124   2017-05-27
# 273125   2017-05-28
# 273126   2017-05-29
# 273127   2017-05-30
# 273128   2017-05-31
# Name: visit_date, Length: 424, dtype: datetime64[ns]
# 163217   2016-07-05
# 163218   2016-07-07
# 163219   2016-07-09
# 163220   2016-07-12
# 163221   2016-07-14
#             ...
# 272032   2017-05-27
# 272033   2017-05-28
# 272034   2017-05-29
# 272035   2017-05-30
# 272036   2017-05-31
# Name: visit_date, Length: 133, dtype: datetime64[ns]
# 163311   2016-07-01
# 163312   2016-07-02
# 163313   2016-07-03
# 163314   2016-07-04
# 163315   2016-07-05
#             ...
# 262126   2017-05-27
# 262127   2017-05-28
# 262128   2017-05-29
# 262129   2017-05-30
# 262130   2017-05-31
# Name: visit_date, Length: 320, dtype: datetime64[ns]
# 163592   2016-07-01
# 163593   2016-07-02
# 163594   2016-07-03
# 163595   2016-07-04
# 163596   2016-07-05
#             ...
# 255535   2017-05-27
# 255536   2017-05-28
# 255537   2017-05-29
# 255538   2017-05-30
# 255539   2017-05-31
# Name: visit_date, Length: 327, dtype: datetime64[ns]
# 163880   2016-07-01
# 163881   2016-07-02
# 163882   2016-07-03
# 163883   2016-07-04
# 163884   2016-07-05
#             ...
# 262906   2017-05-27
# 262907   2017-05-28
# 262908   2017-05-29
# 262909   2017-05-30
# 262910   2017-05-31
# Name: visit_date, Length: 328, dtype: datetime64[ns]
# 164169   2016-07-01
# 164170   2016-07-02
# 164171   2016-07-03
# 164172   2016-07-04
# 164173   2016-07-05
#             ...
# 282562   2017-05-27
# 282563   2017-05-28
# 282564   2017-05-29
# 282565   2017-05-30
# 282566   2017-05-31
# Name: visit_date, Length: 328, dtype: datetime64[ns]
# 164458   2016-01-06
# 164459   2016-01-07
# 164460   2016-01-08
# 164461   2016-01-09
# 164462   2016-01-10
#             ...
# 273436   2017-05-27
# 273437   2017-05-28
# 273438   2017-05-29
# 273439   2017-05-30
# 273440   2017-05-31
# Name: visit_date, Length: 493, dtype: datetime64[ns]
# 164912   2016-09-02
# 164913   2016-09-03
# 164914   2016-09-04
# 164915   2016-09-05
# 164916   2016-09-06
#             ...
# 254521   2017-05-27
# 254522   2017-05-28
# 254523   2017-05-29
# 254524   2017-05-30
# 254525   2017-05-31
# Name: visit_date, Length: 270, dtype: datetime64[ns]
# 165143   2016-07-01
# 165144   2016-07-02
# 165145   2016-07-04
# 165146   2016-07-05
# 165147   2016-07-06
#             ...
# 274762   2017-05-27
# 274763   2017-05-28
# 274764   2017-05-29
# 274765   2017-05-30
# 274766   2017-05-31
# Name: visit_date, Length: 297, dtype: datetime64[ns]
# 165401   2016-01-04
# 165402   2016-01-05
# 165403   2016-01-06
# 165404   2016-01-07
# 165405   2016-01-08
#             ...
# 278857   2017-05-27
# 278858   2017-05-28
# 278859   2017-05-29
# 278860   2017-05-30
# 278861   2017-05-31
# Name: visit_date, Length: 447, dtype: datetime64[ns]
# 165809   2016-01-05
# 165810   2016-01-06
# 165811   2016-01-07
# 165812   2016-01-08
# 165813   2016-01-09
#             ...
# 261736   2017-05-27
# 261737   2017-05-28
# 261738   2017-05-29
# 261739   2017-05-30
# 261740   2017-05-31
# Name: visit_date, Length: 432, dtype: datetime64[ns]
# 166202   2016-07-01
# 166203   2016-07-02
# 166204   2016-07-03
# 166205   2016-07-04
# 166206   2016-07-06
#             ...
# 282640   2017-05-27
# 282641   2017-05-28
# 282642   2017-05-29
# 282643   2017-05-30
# 282644   2017-05-31
# Name: visit_date, Length: 295, dtype: datetime64[ns]
# 166458   2016-01-05
# 166459   2016-01-06
# 166460   2016-01-07
# 166461   2016-01-08
# 166462   2016-01-09
#             ...
# 275191   2017-05-27
# 275192   2017-05-28
# 275193   2017-05-29
# 275194   2017-05-30
# 275195   2017-05-31
# Name: visit_date, Length: 432, dtype: datetime64[ns]
# 166851   2016-07-01
# 166852   2016-07-02
# 166853   2016-07-03
# 166854   2016-07-04
# 166855   2016-07-05
#             ...
# 280651   2017-05-27
# 280652   2017-05-28
# 280653   2017-05-29
# 280654   2017-05-30
# 280655   2017-05-31
# Name: visit_date, Length: 326, dtype: datetime64[ns]
# 167138   2016-07-01
# 167139   2016-07-02
# 167140   2016-07-03
# 167141   2016-07-05
# 167142   2016-07-06
#             ...
# 268210   2017-05-27
# 268211   2017-05-28
# 268212   2017-05-29
# 268213   2017-05-30
# 268214   2017-05-31
# Name: visit_date, Length: 289, dtype: datetime64[ns]
# 167388   2016-07-01
# 167389   2016-07-02
# 167390   2016-07-03
# 167391   2016-07-04
# 167392   2016-07-06
#             ...
# 271252   2017-05-27
# 271253   2017-05-28
# 271254   2017-05-29
# 271255   2017-05-30
# 271256   2017-05-31
# Name: visit_date, Length: 280, dtype: datetime64[ns]
# 167629   2016-07-01
# 167630   2016-07-02
# 167631   2016-07-04
# 167632   2016-07-05
# 167633   2016-07-06
#             ...
# 280768   2017-05-27
# 280769   2017-05-28
# 280770   2017-05-29
# 280771   2017-05-30
# 280772   2017-05-31
# Name: visit_date, Length: 233, dtype: datetime64[ns]
# 167823   2016-07-01
# 167824   2016-07-02
# 167825   2016-07-04
# 167826   2016-07-05
# 167827   2016-07-06
#             ...
# 272383   2017-05-27
# 272384   2017-05-28
# 272385   2017-05-29
# 272386   2017-05-30
# 272387   2017-05-31
# Name: visit_date, Length: 303, dtype: datetime64[ns]
# 168087   2016-07-01
# 168088   2016-07-05
# 168089   2016-07-06
# 168090   2016-07-07
# 168091   2016-07-08
#             ...
# 280417   2017-05-27
# 280418   2017-05-28
# 280419   2017-05-29
# 280420   2017-05-30
# 280421   2017-05-31
# Name: visit_date, Length: 280, dtype: datetime64[ns]
# 168328   2016-07-01
# 168329   2016-07-02
# 168330   2016-07-03
# 168331   2016-07-04
# 168332   2016-07-05
#             ...
# 254053   2017-05-27
# 254054   2017-05-28
# 254055   2017-05-29
# 254056   2017-05-30
# 254057   2017-05-31
# Name: visit_date, Length: 331, dtype: datetime64[ns]
# 168620   2016-07-01
# 168621   2016-07-02
# 168622   2016-07-03
# 168623   2016-07-04
# 168624   2016-07-05
#             ...
# 273943   2017-05-27
# 273944   2017-05-28
# 273945   2017-05-29
# 273946   2017-05-30
# 273947   2017-05-31
# Name: visit_date, Length: 317, dtype: datetime64[ns]
# 168898   2016-07-01
# 168899   2016-07-02
# 168900   2016-07-03
# 168901   2016-07-04
# 168902   2016-07-05
#             ...
# 262321   2017-05-27
# 262322   2017-05-28
# 262323   2017-05-29
# 262324   2017-05-30
# 262325   2017-05-31
# Name: visit_date, Length: 309, dtype: datetime64[ns]
# 169168   2016-01-04
# 169169   2016-01-05
# 169170   2016-01-06
# 169171   2016-01-07
# 169172   2016-01-08
#             ...
# 272617   2017-05-27
# 272618   2017-05-28
# 272619   2017-05-29
# 272620   2017-05-30
# 272621   2017-05-31
# Name: visit_date, Length: 500, dtype: datetime64[ns]
# 169629   2016-07-01
# 169630   2016-07-02
# 169631   2016-07-03
# 169632   2016-07-04
# 169633   2016-07-05
#             ...
# 280534   2017-05-27
# 280535   2017-05-28
# 280536   2017-05-29
# 280537   2017-05-30
# 280538   2017-05-31
# Name: visit_date, Length: 289, dtype: datetime64[ns]
# 169879   2016-01-05
# 169880   2016-01-06
# 169881   2016-01-07
# 169882   2016-01-08
# 169883   2016-01-09
#             ...
# 277609   2017-05-27
# 277610   2017-05-28
# 277611   2017-05-29
# 277612   2017-05-30
# 277613   2017-05-31
# Name: visit_date, Length: 468, dtype: datetime64[ns]
# 170308   2016-01-04
# 170309   2016-01-05
# 170310   2016-01-06
# 170311   2016-01-07
# 170312   2016-01-08
#             ...
# 260683   2017-05-27
# 260684   2017-05-28
# 260685   2017-05-29
# 260686   2017-05-30
# 260687   2017-05-31
# Name: visit_date, Length: 267, dtype: datetime64[ns]
# 170536   2016-01-02
# 170537   2016-01-03
# 170538   2016-01-04
# 170539   2016-01-05
# 170540   2016-01-06
#             ...
# 264895   2017-05-27
# 264896   2017-05-28
# 264897   2017-05-29
# 264898   2017-05-30
# 264899   2017-05-31
# Name: visit_date, Length: 436, dtype: datetime64[ns]
# 170933   2016-01-04
# 170934   2016-01-05
# 170935   2016-01-06
# 170936   2016-01-07
# 170937   2016-01-08
#             ...
# 253546   2017-05-27
# 253547   2017-05-28
# 253548   2017-05-29
# 253549   2017-05-30
# 253550   2017-05-31
# Name: visit_date, Length: 420, dtype: datetime64[ns]
# 171314   2016-01-01
# 171315   2016-01-02
# 171316   2016-01-03
# 171317   2016-01-04
# 171318   2016-01-05
#             ...
# 252610   2017-05-27
# 252611   2017-05-28
# 252612   2017-05-29
# 252613   2017-05-30
# 252614   2017-05-31
# Name: visit_date, Length: 507, dtype: datetime64[ns]
# 171782   2016-07-01
# 171783   2016-07-02
# 171784   2016-07-04
# 171785   2016-07-05
# 171786   2016-07-06
#             ...
# 253039   2017-05-27
# 253040   2017-05-28
# 253041   2017-05-29
# 253042   2017-05-30
# 253043   2017-05-31
# Name: visit_date, Length: 320, dtype: datetime64[ns]
# 172063   2016-07-01
# 172064   2016-07-02
# 172065   2016-07-03
# 172066   2016-07-04
# 172067   2016-07-05
#             ...
# 281743   2017-05-27
# 281744   2017-05-28
# 281745   2017-05-29
# 281746   2017-05-30
# 281747   2017-05-31
# Name: visit_date, Length: 332, dtype: datetime64[ns]
# 172356   2016-07-01
# 172357   2016-07-02
# 172358   2016-07-03
# 172359   2016-07-05
# 172360   2016-07-06
#             ...
# 263257   2017-05-27
# 263258   2017-05-28
# 263259   2017-05-29
# 263260   2017-05-30
# 263261   2017-05-31
# Name: visit_date, Length: 278, dtype: datetime64[ns]
# 172595   2016-01-04
# 172596   2016-01-05
# 172597   2016-01-06
# 172598   2016-01-07
# 172599   2016-01-08
#             ...
# 278779   2017-05-27
# 278780   2017-05-28
# 278781   2017-05-29
# 278782   2017-05-30
# 278783   2017-05-31
# Name: visit_date, Length: 443, dtype: datetime64[ns]
# 172999   2016-07-01
# 173000   2016-07-02
# 173001   2016-07-05
# 173002   2016-07-06
# 173003   2016-07-07
#             ...
# 273514   2017-05-27
# 273515   2017-05-28
# 273516   2017-05-29
# 273517   2017-05-30
# 273518   2017-05-31
# Name: visit_date, Length: 285, dtype: datetime64[ns]
# 173245   2016-01-03
# 173246   2016-01-07
# 173247   2016-01-08
# 173248   2016-01-09
# 173249   2016-01-11
#             ...
# 256393   2017-05-27
# 256394   2017-05-28
# 256395   2017-05-29
# 256396   2017-05-30
# 256397   2017-05-31
# Name: visit_date, Length: 408, dtype: datetime64[ns]
# 173614   2016-01-05
# 173615   2016-01-06
# 173616   2016-01-07
# 173617   2016-01-08
# 173618   2016-01-09
#             ...
# 276400   2017-05-27
# 276401   2017-05-28
# 276402   2017-05-29
# 276403   2017-05-30
# 276404   2017-05-31
# Name: visit_date, Length: 465, dtype: datetime64[ns]
# 174040   2016-01-07
# 174041   2016-01-08
# 174042   2016-01-09
# 174043   2016-01-10
# 174044   2016-01-11
#             ...
# 254560   2017-05-27
# 254561   2017-05-28
# 254562   2017-05-29
# 254563   2017-05-30
# 254564   2017-05-31
# Name: visit_date, Length: 449, dtype: datetime64[ns]
# 174450   2016-01-04
# 174451   2016-01-05
# 174452   2016-01-06
# 174453   2016-01-07
# 174454   2016-01-08
#             ...
# 269146   2017-05-27
# 269147   2017-05-28
# 269148   2017-05-29
# 269149   2017-05-30
# 269150   2017-05-31
# Name: visit_date, Length: 509, dtype: datetime64[ns]
# 174920   2016-07-01
# 174921   2016-07-02
# 174922   2016-07-03
# 174923   2016-07-04
# 174924   2016-07-05
#             ...
# 253390   2017-05-27
# 253391   2017-05-28
# 253392   2017-05-29
# 253393   2017-05-30
# 253394   2017-05-31
# Name: visit_date, Length: 325, dtype: datetime64[ns]
# 175206   2016-01-01
# 175207   2016-01-02
# 175208   2016-01-03
# 175209   2016-01-04
# 175210   2016-01-05
#             ...
# 266104   2017-05-27
# 266105   2017-05-28
# 266106   2017-05-29
# 266107   2017-05-30
# 266108   2017-05-31
# Name: visit_date, Length: 514, dtype: datetime64[ns]
# 175681   2017-02-09
# 175682   2017-02-12
# 175683   2017-02-13
# 175684   2017-02-14
# 175685   2017-02-15
#             ...
# 275698   2017-05-27
# 275699   2017-05-28
# 275700   2017-05-29
# 275701   2017-05-30
# 275702   2017-05-31
# Name: visit_date, Length: 105, dtype: datetime64[ns]
# 175747   2016-07-01
# 175748   2016-07-02
# 175749   2016-07-03
# 175750   2016-07-04
# 175751   2016-07-05
#             ...
# 260878   2017-05-27
# 260879   2017-05-28
# 260880   2017-05-29
# 260881   2017-05-30
# 260882   2017-05-31
# Name: visit_date, Length: 293, dtype: datetime64[ns]
# 176001   2016-01-03
# 176002   2016-01-04
# 176003   2016-01-05
# 176004   2016-01-06
# 176005   2016-01-07
#             ...
# 275932   2017-05-27
# 275933   2017-05-28
# 275934   2017-05-29
# 275935   2017-05-30
# 275936   2017-05-31
# Name: visit_date, Length: 484, dtype: datetime64[ns]
# 176446   2016-01-04
# 176447   2016-01-05
# 176448   2016-01-06
# 176449   2016-01-07
# 176450   2016-01-08
#             ...
# 267430   2017-05-27
# 267431   2017-05-28
# 267432   2017-05-29
# 267433   2017-05-30
# 267434   2017-05-31
# Name: visit_date, Length: 507, dtype: datetime64[ns]
# 176914   2016-07-01
# 176915   2016-07-02
# 176916   2016-07-03
# 176917   2016-07-04
# 176918   2016-07-05
#             ...
# 269965   2017-05-27
# 269966   2017-05-28
# 269967   2017-05-29
# 269968   2017-05-30
# 269969   2017-05-31
# Name: visit_date, Length: 323, dtype: datetime64[ns]
# 177198   2016-01-04
# 177199   2016-01-05
# 177200   2016-01-06
# 177201   2016-01-07
# 177202   2016-01-08
#             ...
# 280924   2017-05-27
# 280925   2017-05-28
# 280926   2017-05-29
# 280927   2017-05-30
# 280928   2017-05-31
# Name: visit_date, Length: 440, dtype: datetime64[ns]
# 177599   2016-07-01
# 177600   2016-07-02
# 177601   2016-07-03
# 177602   2016-07-04
# 177603   2016-07-05
#             ...
# 254131   2017-05-27
# 254132   2017-05-28
# 254133   2017-05-29
# 254134   2017-05-30
# 254135   2017-05-31
# Name: visit_date, Length: 292, dtype: datetime64[ns]
# 177852   2016-07-01
# 177853   2016-07-04
# 177854   2016-07-05
# 177855   2016-07-06
# 177856   2016-07-07
#             ...
# 282484   2017-05-27
# 282485   2017-05-28
# 282486   2017-05-29
# 282487   2017-05-30
# 282488   2017-05-31
# Name: visit_date, Length: 252, dtype: datetime64[ns]
# 178065   2016-01-05
# 178066   2016-01-06
# 178067   2016-01-07
# 178068   2016-01-08
# 178069   2016-01-09
#             ...
# 271369   2017-05-27
# ...
# 255301   2017-05-27
# 255302   2017-05-28
# 255303   2017-05-29
# 255304   2017-05-30
# 255305   2017-05-31
# Name: visit_date, Length: 187, dtype: datetime64[ns]
# 234445   2016-01-05
# 234446   2016-01-06
# 234447   2016-01-07
# 234448   2016-01-08
# 234449   2016-01-09
#             ...
# 258187   2017-05-27
# 258188   2017-05-28
# 258189   2017-05-29
# 258190   2017-05-30
# 258191   2017-05-31
# Name: visit_date, Length: 439, dtype: datetime64[ns]
# 234845   2016-07-14
# 234846   2016-07-15
# 234847   2016-07-16
# 234848   2016-07-17
# 234849   2016-07-18
#             ...
# 266260   2017-05-27
# 266261   2017-05-28
# 266262   2017-05-29
# 266263   2017-05-30
# 266264   2017-05-31
# Name: visit_date, Length: 281, dtype: datetime64[ns]
# 235087   2016-01-08
# 235088   2016-01-09
# 235089   2016-01-10
# 235090   2016-01-11
# 235091   2016-01-12
#             ...
# 260059   2017-05-27
# 260060   2017-05-28
# 260061   2017-05-29
# 260062   2017-05-30
# 260063   2017-05-31
# Name: visit_date, Length: 480, dtype: datetime64[ns]
# 235528   2016-07-01
# 235529   2016-07-02
# 235530   2016-07-03
# 235531   2016-07-04
# 235532   2016-07-05
#             ...
# 275074   2017-05-27
# 275075   2017-05-28
# 275076   2017-05-29
# 275077   2017-05-30
# 275078   2017-05-31
# Name: visit_date, Length: 274, dtype: datetime64[ns]
# 235763   2016-01-04
# 235764   2016-01-05
# 235765   2016-01-06
# 235766   2016-01-07
# 235767   2016-01-08
#             ...
# 259552   2017-05-27
# 259553   2017-05-28
# 259554   2017-05-29
# 259555   2017-05-30
# 259556   2017-05-31
# Name: visit_date, Length: 446, dtype: datetime64[ns]
# 236170   2016-01-05
# 236171   2016-01-06
# 236172   2016-01-07
# 236173   2016-01-08
# 236174   2016-01-09
#             ...
# 264232   2017-05-27
# 264233   2017-05-28
# 264234   2017-05-29
# 264235   2017-05-30
# 264236   2017-05-31
# Name: visit_date, Length: 422, dtype: datetime64[ns]
# 236553   2016-07-01
# 236554   2016-07-02
# 236555   2016-07-03
# 236556   2016-07-04
# 236557   2016-07-05
#             ...
# 257797   2017-05-27
# 257798   2017-05-28
# 257799   2017-05-29
# 257800   2017-05-30
# 257801   2017-05-31
# Name: visit_date, Length: 323, dtype: datetime64[ns]
# 236837   2016-07-01
# 236838   2016-07-02
# 236839   2016-07-03
# 236840   2016-07-06
# 236841   2016-07-07
#             ...
# 266455   2017-05-27
# 266456   2017-05-28
# 266457   2017-05-29
# 266458   2017-05-30
# 266459   2017-05-31
# Name: visit_date, Length: 241, dtype: datetime64[ns]
# 237039   2016-07-01
# 237040   2016-07-02
# 237041   2016-07-04
# 237042   2016-07-05
# 237043   2016-07-06
#             ...
# 275581   2017-05-27
# 275582   2017-05-28
# 275583   2017-05-29
# 275584   2017-05-30
# 275585   2017-05-31
# Name: visit_date, Length: 254, dtype: datetime64[ns]
# 237254   2016-07-01
# 237255   2016-07-02
# 237256   2016-07-03
# 237257   2016-07-04
# 237258   2016-07-05
#             ...
# 279403   2017-05-27
# 279404   2017-05-28
# 279405   2017-05-29
# 279406   2017-05-30
# 279407   2017-05-31
# Name: visit_date, Length: 330, dtype: datetime64[ns]
# 237545   2016-01-21
# 237546   2016-01-22
# 237547   2016-01-23
# 237548   2016-01-24
# 237549   2016-01-26
#             ...
# 283459   2017-05-27
# 283460   2017-05-28
# 283461   2017-05-29
# 283462   2017-05-30
# 283463   2017-05-31
# Name: visit_date, Length: 407, dtype: datetime64[ns]
# 237913   2016-07-01
# 237914   2016-07-02
# 237915   2016-07-03
# 237916   2016-07-04
# 237917   2016-07-05
#             ...
# 262165   2017-05-27
# 262166   2017-05-28
# 262167   2017-05-29
# 262168   2017-05-30
# 262169   2017-05-31
# Name: visit_date, Length: 303, dtype: datetime64[ns]
# 238177   2016-07-01
# 238178   2016-07-02
# 238179   2016-07-04
# 238180   2016-07-06
# 238181   2016-07-20
#             ...
# 268990   2017-05-27
# 268991   2017-05-28
# 268992   2017-05-29
# 268993   2017-05-30
# 268994   2017-05-31
# Name: visit_date, Length: 211, dtype: datetime64[ns]
# 238349   2016-03-25
# 238350   2016-03-26
# 238351   2016-03-29
# 238352   2016-03-30
# 238353   2016-03-31
#             ...
# 274606   2017-05-27
# 274607   2017-05-28
# 274608   2017-05-29
# 274609   2017-05-30
# 274610   2017-05-31
# Name: visit_date, Length: 193, dtype: datetime64[ns]
# 238503   2016-01-01
# 238504   2016-01-05
# 238505   2016-01-06
# 238506   2016-01-07
# 238507   2016-01-08
#             ...
# 265948   2017-05-27
# 265949   2017-05-28
# 265950   2017-05-29
# 265951   2017-05-30
# 265952   2017-05-31
# Name: visit_date, Length: 473, dtype: datetime64[ns]
# 238937   2016-01-05
# 238938   2016-01-06
# 238939   2016-01-07
# 238940   2016-01-08
# 238941   2016-01-09
#             ...
# 282328   2017-05-27
# 282329   2017-05-28
# 282330   2017-05-29
# 282331   2017-05-30
# 282332   2017-05-31
# Name: visit_date, Length: 434, dtype: datetime64[ns]
# 239332   2016-01-05
# 239333   2016-01-06
# 239334   2016-01-08
# 239335   2016-01-09
# 239336   2016-01-10
#             ...
# 257992   2017-05-27
# 257993   2017-05-28
# 257994   2017-05-29
# 257995   2017-05-30
# 257996   2017-05-31
# Name: visit_date, Length: 441, dtype: datetime64[ns]
# 239734   2016-07-01
# 239735   2016-07-02
# 239736   2016-07-03
# 239737   2016-07-05
# 239738   2016-07-06
#             ...
# 256315   2017-05-27
# 256316   2017-05-28
# 256317   2017-05-29
# 256318   2017-05-30
# 256319   2017-05-31
# Name: visit_date, Length: 283, dtype: datetime64[ns]
# 239978   2016-07-01
# 239979   2016-07-07
# 239980   2016-07-08
# 239981   2016-07-09
# 239982   2016-07-10
#             ...
# 275737   2017-05-27
# 275738   2017-05-28
# 275739   2017-05-29
# 275740   2017-05-30
# 275741   2017-05-31
# Name: visit_date, Length: 259, dtype: datetime64[ns]
# 240198   2016-07-01
# 240199   2016-07-02
# 240200   2016-07-08
# 240201   2016-07-09
# 240202   2016-07-15
#             ...
# 254287   2017-05-27
# 254288   2017-05-28
# 254289   2017-05-29
# 254290   2017-05-30
# 254291   2017-05-31
# Name: visit_date, Length: 205, dtype: datetime64[ns]
# 240364   2016-01-08
# 240365   2016-01-09
# 240366   2016-01-10
# 240367   2016-01-11
# 240368   2016-01-12
#             ...
# 262867   2017-05-27
# 262868   2017-05-28
# 262869   2017-05-29
# 262870   2017-05-30
# 262871   2017-05-31
# Name: visit_date, Length: 397, dtype: datetime64[ns]
# 240722   2016-01-01
# 240723   2016-01-06
# 240724   2016-01-07
# 240725   2016-01-08
# 240726   2016-01-09
#             ...
# 277882   2017-05-27
# 277883   2017-05-28
# 277884   2017-05-29
# 277885   2017-05-30
# 277886   2017-05-31
# Name: visit_date, Length: 512, dtype: datetime64[ns]
# 241195   2016-07-01
# 241196   2016-07-02
# 241197   2016-07-03
# 241198   2016-07-04
# 241199   2016-07-05
#             ...
# 257446   2017-05-27
# 257447   2017-05-28
# 257448   2017-05-29
# 257449   2017-05-30
# 257450   2017-05-31
# Name: visit_date, Length: 289, dtype: datetime64[ns]
# 241445   2016-07-01
# 241446   2016-07-02
# 241447   2016-07-04
# 241448   2016-07-05
# 241449   2016-07-06
#             ...
# 275776   2017-05-27
# 275777   2017-05-28
# 275778   2017-05-29
# 275779   2017-05-30
# 275780   2017-05-31
# Name: visit_date, Length: 301, dtype: datetime64[ns]
# 241707   2016-07-01
# 241708   2016-07-02
# 241709   2016-07-03
# 241710   2016-07-04
# 241711   2016-07-06
#             ...
# 259786   2017-05-27
# 259787   2017-05-28
# 259788   2017-05-29
# 259789   2017-05-30
# 259790   2017-05-31
# Name: visit_date, Length: 320, dtype: datetime64[ns]
# 241988   2016-07-01
# 241989   2016-07-02
# 241990   2016-07-04
# 241991   2016-07-05
# 241992   2016-07-06
#             ...
# 262399   2017-05-27
# 262400   2017-05-28
# 262401   2017-05-29
# 262402   2017-05-30
# 262403   2017-05-31
# Name: visit_date, Length: 306, dtype: datetime64[ns]
# 242255   2016-01-05
# 242256   2016-01-07
# 242257   2016-01-08
# 242258   2016-01-09
# 242259   2016-01-12
#             ...
# 256744   2017-05-27
# 256745   2017-05-28
# 256746   2017-05-29
# 256747   2017-05-30
# 256748   2017-05-31
# Name: visit_date, Length: 418, dtype: datetime64[ns]
# 242634   2016-01-01
# 242635   2016-01-02
# 242636   2016-01-03
# 242637   2016-01-04
# 242638   2016-01-05
#             ...
# 258967   2017-05-27
# 258968   2017-05-28
# 258969   2017-05-29
# 258970   2017-05-30
# 258971   2017-05-31
# Name: visit_date, Length: 497, dtype: datetime64[ns]
# 243092   2016-07-01
# 243093   2016-07-02
# 243094   2016-07-03
# 243095   2016-07-04
# 243096   2016-07-05
#             ...
# 262243   2017-05-27
# 262244   2017-05-28
# 262245   2017-05-29
# 262246   2017-05-30
# 262247   2017-05-31
# Name: visit_date, Length: 288, dtype: datetime64[ns]
# 243341   2016-07-01
# 243342   2016-07-02
# 243343   2016-07-04
# 243344   2016-07-05
# 243345   2016-07-06
#             ...
# 279247   2017-05-27
# 279248   2017-05-28
# 279249   2017-05-29
# 279250   2017-05-30
# 279251   2017-05-31
# Name: visit_date, Length: 286, dtype: datetime64[ns]
# 243588   2016-01-05
# 243589   2016-01-06
# 243590   2016-01-07
# 243591   2016-01-08
# 243592   2016-01-09
#             ...
# 281392   2017-05-27
# 281393   2017-05-28
# 281394   2017-05-29
# 281395   2017-05-30
# 281396   2017-05-31
# Name: visit_date, Length: 437, dtype: datetime64[ns]
# 243986   2016-07-01
# 243987   2016-07-02
# 243988   2016-07-04
# 243989   2016-07-05
# 243990   2016-07-06
#             ...
# 259240   2017-05-27
# 259241   2017-05-28
# 259242   2017-05-29
# 259243   2017-05-30
# 259244   2017-05-31
# Name: visit_date, Length: 282, dtype: datetime64[ns]
# 244229   2016-07-01
# 244230   2016-07-02
# 244231   2016-07-03
# 244232   2016-07-04
# 244233   2016-07-05
#             ...
# 260722   2017-05-27
# 260723   2017-05-28
# 260724   2017-05-29
# 260725   2017-05-30
# 260726   2017-05-31
# Name: visit_date, Length: 331, dtype: datetime64[ns]
# 244521   2016-07-17
# 244522   2016-07-29
# 244523   2016-07-31
# 244524   2016-08-09
# 244525   2016-08-18
#             ...
# 260761   2017-05-27
# 260762   2017-05-28
# 260763   2017-05-29
# 260764   2017-05-30
# 260765   2017-05-31
# Name: visit_date, Length: 153, dtype: datetime64[ns]
# 244635   2016-01-04
# 244636   2016-01-05
# 244637   2016-01-06
# 244638   2016-01-07
# 244639   2016-01-08
#             ...
# 263998   2017-05-27
# 263999   2017-05-28
# 264000   2017-05-29
# 264001   2017-05-30
# 264002   2017-05-31
# Name: visit_date, Length: 509, dtype: datetime64[ns]
# 245105   2016-07-03
# 245106   2016-07-04
# 245107   2016-07-05
# 245108   2016-07-06
# 245109   2016-07-07
#             ...
# 252259   2017-05-27
# 252260   2017-05-28
# 252261   2017-05-29
# 252262   2017-05-30
# 252263   2017-05-31
# Name: visit_date, Length: 155, dtype: datetime64[ns]
# 245221   2016-07-01
# 245222   2016-07-02
# 245223   2016-07-03
# 245224   2016-07-04
# 245225   2016-07-05
#             ...
# 254365   2017-05-27
# 254366   2017-05-28
# 254367   2017-05-29
# 254368   2017-05-30
# 254369   2017-05-31
# Name: visit_date, Length: 319, dtype: datetime64[ns]
# 245501   2016-07-01
# 245502   2016-07-02
# 245503   2016-07-03
# 245504   2016-07-05
# 245505   2016-07-06
#             ...
# 279481   2017-05-27
# 279482   2017-05-28
# 279483   2017-05-29
# 279484   2017-05-30
# 279485   2017-05-31
# Name: visit_date, Length: 272, dtype: datetime64[ns]
# 245734   2016-01-03
# 245735   2016-01-04
# 245736   2016-01-05
# 245737   2016-01-06
# 245738   2016-01-07
#             ...
# 282367   2017-05-27
# 282368   2017-05-28
# 282369   2017-05-29
# 282370   2017-05-30
# 282371   2017-05-31
# Name: visit_date, Length: 440, dtype: datetime64[ns]
# 246135   2016-07-01
# 246136   2016-07-02
# 246137   2016-07-03
# 246138   2016-07-04
# 246139   2016-07-05
#             ...
# 260605   2017-05-27
# 260606   2017-05-28
# 260607   2017-05-29
# 260608   2017-05-30
# 260609   2017-05-31
# Name: visit_date, Length: 333, dtype: datetime64[ns]
# 246429   2016-01-01
# 246430   2016-01-02
# 246431   2016-01-03
# 246432   2016-01-07
# 246433   2016-01-08
#             ...
# 261502   2017-05-27
# 261503   2017-05-28
# 261504   2017-05-29
# 261505   2017-05-30
# 261506   2017-05-31
# Name: visit_date, Length: 487, dtype: datetime64[ns]
# 246877   2016-01-06
# 246878   2016-01-08
# 246879   2016-01-09
# 246880   2016-01-10
# 246881   2016-01-11
#             ...
# 254950   2017-05-27
# 254951   2017-05-28
# 254952   2017-05-29
# 254953   2017-05-30
# 254954   2017-05-31
# Name: visit_date, Length: 464, dtype: datetime64[ns]
# 247302   2016-07-01
# 247303   2016-07-02
# 247304   2016-07-03
# 247305   2016-07-04
# 247306   2016-07-05
#             ...
# 273202   2017-05-27
# 273203   2017-05-28
# 273204   2017-05-29
# 273205   2017-05-30
# 273206   2017-05-31
# Name: visit_date, Length: 333, dtype: datetime64[ns]
# 247596   2016-01-06
# 247597   2016-01-07
# 247598   2016-01-09
# 247599   2016-01-10
# 247600   2016-01-11
#             ...
# 253663   2017-05-27
# 253664   2017-05-28
# 253665   2017-05-29
# 253666   2017-05-30
# 253667   2017-05-31
# Name: visit_date, Length: 406, dtype: datetime64[ns]
# 247963   2016-07-01
# 247964   2016-07-02
# 247965   2016-07-04
# 247966   2016-07-05
# 247967   2016-07-06
#             ...
# 257290   2017-05-27
# 257291   2017-05-28
# 257292   2017-05-29
# 257293   2017-05-30
# 257294   2017-05-31
# Name: visit_date, Length: 289, dtype: datetime64[ns]
# 248213   2016-07-01
# 248214   2016-07-02
# 248215   2016-07-04
# 248216   2016-07-05
# 248217   2016-07-06
#             ...
# 267313   2017-05-27
# 267314   2017-05-28
# 267315   2017-05-29
# 267316   2017-05-30
# 267317   2017-05-31
# Name: visit_date, Length: 265, dtype: datetime64[ns]
# 248439   2016-01-29
# 248440   2016-02-02
# 248441   2016-02-03
# 248442   2016-02-04
# 248443   2016-02-05
#             ...
# 276244   2017-05-27
# 276245   2017-05-28
# 276246   2017-05-29
# 276247   2017-05-30
# 276248   2017-05-31
# Name: visit_date, Length: 403, dtype: datetime64[ns]
# 248803   2016-07-01
# 248804   2016-07-02
# 248805   2016-07-03
# 248806   2016-07-05
# 248807   2016-07-06
#             ...
# 266533   2017-05-27
# 266534   2017-05-28
# 266535   2017-05-29
# 266536   2017-05-30
# 266537   2017-05-31
# Name: visit_date, Length: 293, dtype: datetime64[ns]
# 249057   2016-01-04
# 249058   2016-01-05
# 249059   2016-01-06
# 249060   2016-01-07
# 249061   2016-01-08
#             ...
# 281314   2017-05-27
# 281315   2017-05-28
# 281316   2017-05-29
# 281317   2017-05-30
# 281318   2017-05-31
# Name: visit_date, Length: 453, dtype: datetime64[ns]
# 249471   2016-01-04
# 249472   2016-01-05
# 249473   2016-01-07
# 249474   2016-01-08
# 249475   2016-01-09
#             ...
# 267118   2017-05-27
# 267119   2017-05-28
# 267120   2017-05-29
# 267121   2017-05-30
# 267122   2017-05-31
# Name: visit_date, Length: 349, dtype: datetime64[ns]
# 249781   2016-07-01
# 249782   2016-07-02
# 249783   2016-07-04
# 249784   2016-07-05
# 249785   2016-07-06
#             ...
# 253078   2017-05-27
# 253079   2017-05-28
# 253080   2017-05-29
# 253081   2017-05-30
# 253082   2017-05-31
# Name: visit_date, Length: 279, dtype: datetime64[ns]
# 250021   2016-07-01
# 250022   2016-07-02
# 250023   2016-07-03
# 250024   2016-07-04
# 250025   2016-07-05
#             ...
# 275035   2017-05-27
# 275036   2017-05-28
# 275037   2017-05-29
# 275038   2017-05-30
# 275039   2017-05-31
# Name: visit_date, Length: 303, dtype: datetime64[ns]
# 250285   2016-12-12
# 250286   2016-12-13
# 250287   2016-12-14
# 250288   2016-12-15
# 250289   2016-12-16
#             ...
# 257641   2017-05-27
# 257642   2017-05-28
# 257643   2017-05-29
# 257644   2017-05-30
# 257645   2017-05-31
# Name: visit_date, Length: 150, dtype: datetime64[ns]
# 250396   2016-07-01
# 250397   2016-07-02
# 250398   2016-07-03
# 250399   2016-07-04
# 250400   2016-07-05
#             ...
# 254482   2017-05-27
# 254483   2017-05-28
# 254484   2017-05-29
# 254485   2017-05-30
# 254486   2017-05-31
# Name: visit_date, Length: 332, dtype: datetime64[ns]
# 250689   2016-01-15
# 250690   2016-01-16
# 250691   2016-01-17
# 250692   2016-01-18
# 250693   2016-01-19
#             ...
# 265441   2017-05-27
# 265442   2017-05-28
# 265443   2017-05-29
# 265444   2017-05-30
# 265445   2017-05-31
# Name: visit_date, Length: 493, dtype: datetime64[ns]
# 251143   2016-02-22
# 251144   2016-02-23
# 251145   2016-02-24
# 251146   2016-02-25
# 251147   2016-02-26
#             ...
# 253780   2017-05-27
# 253781   2017-05-28
# 253782   2017-05-29
# 253783   2017-05-30
# 253784   2017-05-31
# Name: visit_date, Length: 424, dtype: datetime64[ns]
# 251528   2016-03-24
# 251529   2016-03-28
# 251530   2016-03-29
# 251531   2016-03-30
# 251532   2016-03-31
#             ...
# 277258   2017-05-27
# 277259   2017-05-28
# 277260   2017-05-29
# 277261   2017-05-30
# 277262   2017-05-31
# Name: visit_date, Length: 385, dtype: datetime64[ns]
# 251874   2016-07-01
# 251875   2016-07-02
# 251876   2016-07-04
# 251877   2016-07-05
# 251878   2016-07-06
#             ...
# 255886   2017-05-27
# 255887   2017-05-28
# 255888   2017-05-29
# 255889   2017-05-30
# 255890   2017-05-31
# Name: visit_date, Length: 273, dtype: datetime64[ns]

# %%
dataset_with_weather['precipitation']=dataset_with_weather['precipitation'].fillna(0)

# %%
dataset_with_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 284127 entries, 0 to 284126
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   store_id         284127 non-null  object
#  1   visit_date       284127 non-null  object
#  2   visitors         284127 non-null  float64
#  3   id               284127 non-null  object
#  4   dow              284127 non-null  int64
#  5   air_genre_name   284127 non-null  int64
#  6   air_area_name    284127 non-null  object
#  7   latitude         284127 non-null  float64
#  8   longitude        284127 non-null  float64
#  9   air_area_name0   284127 non-null  int64
#  10  holiday_flg      284127 non-null  int64
#  11  holiday_flg2     284127 non-null  int64
#  12  precipitation    284127 non-null  float64
#  13  avg_temperature  391 non-null     float64
# dtypes: float64(5), int64(5), object(4)
# memory usage: 32.5+ MB

# %%
def add_weather(dataset):                                                                                                                     
    print('Adding weather...')                                                                                                                
    air_nearest = pd.read_csv(                                                                                                                
        '{}air_store_info_with_nearest_active_station.csv'.format(weather_set_dir))                                                              
    unique_air_store_ids = list(dataset.store_id.unique())                                                                                
                                                                                                                                                                                                            
    weather_keep_columns = ['precipitation', 'avg_temperature']                                                                                                                                   
                                                                                                                                              
    dataset_with_weather = dataset.copy()                                                                                                     
    for column in weather_keep_columns:                                                                                                       
        dataset_with_weather[column] = np.nan                                                                                                 
                                                                                                                                              
    for air_id in unique_air_store_ids:                                                                                                       
        station = air_nearest[air_nearest.air_store_id == air_id].station_id.iloc[0]                                                          
        weather_data = pd.read_csv(weather_data_dir + station + '.csv', parse_dates=['calendar_date']).rename(columns={'calendar_date': 'visit_date'})   
                                                                                                                                              
        this_store = dataset.store_id == air_id 
                                                                                                  
        merged = dataset[this_store].merge(weather_data, on='visit_date', how='left')                                                         
                                                                                                                                              
        for column in weather_keep_columns:                                                                                                   
            dataset_with_weather.loc[this_store, column] = merged[column]                                                                     
    return dataset_with_weather                                                                                                               
                                                                                                                                              
data = add_weather(data)
# Out:
# Adding weather...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-179cc230f1d8> in <module>()
#      22     return dataset_with_weather
#      23
# ---> 24 data = add_weather(data)
#      25
#
# <ipython-input-34-179cc230f1d8> in add_weather(dataset)
#      17         this_store = dataset.store_id == air_id
#      18         #merged = dataset[this_store].merge(weather_data, on='visit_date', how='left')
# ---> 19         merged = dataset_with_weather.merge(weather_data,on='visit_date',how='left')
#      20         for column in weather_keep_columns:
#      21             dataset_with_weather.loc[this_store, column] = merged[column]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7961             copy=copy,
#    7962             indicator=indicator,
# -> 7963             validate=validate,
#    7964         )
#    7965
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
#      89     return op.get_result()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     654         # validate the merge keys dtypes. We may need to coerce
#     655         # to avoid incompatible dtypes
# --> 656         self._maybe_coerce_merge_keys()
#     657
#     658         # If argument passed to validate,
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py in _maybe_coerce_merge_keys(self)
#    1169                 raise ValueError(msg)
#    1170             elif not needs_i8_conversion(lk.dtype) and needs_i8_conversion(rk.dtype):
# -> 1171                 raise ValueError(msg)
#    1172             elif is_datetime64tz_dtype(lk.dtype) and not is_datetime64tz_dtype(
#    1173                 rk.dtype
#
# ValueError: You are trying to merge on object and datetime64[ns] columns. If you wish to proceed you should use pd.concat

# %% [markdown]
# ---

# %%
data_path = '/content/data/'
air_reserve = pd.read_csv(data_path + 'air_reserve.csv.zip').rename(columns={'air_store_id':'store_id'})
hpg_reserve = pd.read_csv(data_path + 'hpg_reserve.csv.zip').rename(columns={'hpg_store_id':'store_id'})
air_store = pd.read_csv(data_path + 'air_store_info.csv.zip').rename(columns={'air_store_id':'store_id'})
hpg_store = pd.read_csv(data_path + 'hpg_store_info.csv.zip').rename(columns={'hpg_store_id':'store_id'})
air_visit = pd.read_csv(data_path + 'air_visit_data.csv.zip').rename(columns={'air_store_id':'store_id'})
store_id_map = pd.read_csv(data_path + 'store_id_relation.csv.zip').set_index('hpg_store_id',drop=False)
date_info = pd.read_csv(data_path + 'date_info.csv.zip').rename(columns={'calendar_date': 'visit_date'}).drop('day_of_week',axis=1)
submission = pd.read_csv(data_path + 'sample_submission.csv.zip')

# %%
submission['visit_date'] = submission['id'].str[-10:]
submission['store_id'] = submission['id'].str[:-11]
air_reserve['visit_date'] = air_reserve['visit_datetime'].str[:10]
air_reserve['reserve_date'] = air_reserve['reserve_datetime'].str[:10]
air_reserve['dow'] = pd.to_datetime(air_reserve['visit_date']).dt.dayofweek
hpg_reserve['visit_date'] = hpg_reserve['visit_datetime'].str[:10]
hpg_reserve['reserve_date'] = hpg_reserve['reserve_datetime'].str[:10]
hpg_reserve['dow'] = pd.to_datetime(hpg_reserve['visit_date']).dt.dayofweek
air_visit['id'] = air_visit['store_id'] + '_' + air_visit['visit_date']
hpg_reserve['store_id'] = hpg_reserve['store_id'].map(store_id_map['air_store_id']).fillna(hpg_reserve['store_id'])
hpg_store['store_id'] = hpg_store['store_id'].map(store_id_map['air_store_id']).fillna(hpg_store['store_id'])
hpg_store.rename(columns={'hpg_genre_name':'air_genre_name','hpg_area_name':'air_area_name'},inplace=True)
data = pd.concat([air_visit, submission]).copy()
data['dow'] = pd.to_datetime(data['visit_date']).dt.dayofweek
date_info['holiday_flg2'] = pd.to_datetime(date_info['visit_date']).dt.dayofweek
date_info['holiday_flg2'] = ((date_info['holiday_flg2']>4) | (date_info['holiday_flg']==1)).astype(int)

air_store['air_area_name0'] = air_store['air_area_name'].apply(lambda x: x.split(' ')[0])

lbl = LabelEncoder()
air_store['air_genre_name'] = lbl.fit_transform(air_store['air_genre_name'])
air_store['air_area_name0'] = lbl.fit_transform(air_store['air_area_name0'])

data['visitors'] = np.log1p(data['visitors'])
data = data.merge(air_store,on='store_id',how='left')
data = data.merge(date_info[['visit_date','holiday_flg','holiday_flg2']], on=['visit_date'],how='left')

# %%
air_store['air_area_name1'] = air_store['air_area_name'].apply(lambda x: ' '.join(x.split(' ')[:2]))
air_store['air_area_name1'] = lbl.fit_transform(air_store['air_area_name1'])
len(pd.unique(air_store['air_area_name1']))
# Out:
# 55

# %%
air_store[['store_id','air_area_name1']]
data = data.merge(air_store[['store_id','air_area_name1']],on='store_id',how='left')

# %%
data['month'] = pd.to_datetime(data['visit_date']).dt.month

# %%
data['expansion_after'] =((pd.to_datetime(data['visit_date']).dt.year >= 2016) | (pd.to_datetime(data['visit_date']).dt.month >= 7)).astype(int)

# %%
data.tail()
# Out:
#                     store_id  visit_date  ...  month expansion_after
# 284122  air_fff68b929994bfbd  2017-05-27  ...      5               1
# 284123  air_fff68b929994bfbd  2017-05-28  ...      5               1
# 284124  air_fff68b929994bfbd  2017-05-29  ...      5               1
# 284125  air_fff68b929994bfbd  2017-05-30  ...      5               1
# 284126  air_fff68b929994bfbd  2017-05-31  ...      5               1
#
# [5 rows x 15 columns]

# %% [markdown]
# #1. data 정제하기

# %%
train_size = len(air_visit)
test = data[train_size:]

restaurant = data.drop("latitude", axis=1).copy()
restaurant.drop("longitude", axis=1, inplace=True)
restaurant.drop("visit_date", axis=1, inplace=True)
restaurant.drop("id", axis=1, inplace=True)
restaurant.drop("store_id", axis=1, inplace=True)
restaurant.drop("air_area_name", axis=1, inplace=True)
restaurant.drop("air_area_name0", axis=1, inplace=True)


train_data = restaurant[:train_size]
test_data = restaurant[train_size:]



y_train = train_data["visitors"].copy()
X_train=train_data.drop("visitors", axis=1).copy() 

X_test = test_data.drop("visitors", axis=1)

# %%
X_train
# Out:
#         dow  air_genre_name  ...  month  expansion_after
# 0         2               4  ...      1                1
# 1         3               4  ...      1                1
# 2         4               4  ...      1                1
# 3         5               4  ...      1                1
# 4         0               4  ...      1                1
# ...     ...             ...  ...    ...              ...
# 252103    1              11  ...      4                1
# 252104    2              11  ...      4                1
# 252105    3              11  ...      4                1
# 252106    4              11  ...      4                1
# 252107    5              11  ...      4                1
#
# [252108 rows x 7 columns]

# %% [markdown]
# # 2. Train

# %% [markdown]
# ## 2.1 Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor
GBR = GradientBoostingRegressor(learning_rate=0.2, random_state=3, n_estimators=200, subsample=0.8, max_depth =10)
GBR.fit(X_train, y_train)

predict=GBR.predict(X_test) # 0.7361

# %%
print('교차 검증별 정확도:',np.round(scores, 4))
print('평균 검증 정확도:', np.round(np.mean(scores), 4))
# Out:
# 교차 검증별 정확도: [nan nan nan nan nan]
# 평균 검증 정확도: nan

# %%
from sklearn.neighbors import KNeighborsRegressor
KNR = KNeighborsRegressor(n_jobs=-1, n_neighbors=4)
KNR.fit(X_train, y_train)

predict=KNR.predict(X_test) # 0.82510

# %%
from xgboost import XGBRegressor
XGB = XGBRegressor(learning_rate=0.2, random_state=3, n_estimators=280, subsample=0.8, 
                      colsample_bytree=0.8, max_depth =12)
XGB.fit(X_train, y_train)
predict=XGB.predict(X_test) # 0.7368
# Out:
# [05:35:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
from sklearn.model_selection import cross_val_score, KFold
scores = cross_val_score(dt_clf , data , label , scoring='accuracy',cv=3)

# %%
import lightgbm as lgb
lgb_train = lgb.Dataset(X_train, y_train)
test
params = {
    
}
params['learning_rate'] = 0.003
params['boosting_type'] = 'gbdt'
params['objective'] = 'regression'
params['metric'] = 'mse'
params['sub_feature'] = 0.5
params['num_leaves'] = 10
params['min_data'] = 50
params['max_depth'] = 10
gbm = lgb.train(params,lgb_train,2300)
predict = gbm.predict(X_test)  #0.78211

# %% [markdown]
# # 그리드 서치

# %%
from lightgbm import LGBMRegressor
from sklearn.model_selection import GridSearchCV
LGBM = LGBMRegressor()
param_grid = {
    'learning rate': [1,0.1, 0.001, 0.003],
    'boosting_type': ['gbdt', 'rf'],
    'max_bin' : [10, 100, 100],
    'num_leaves': [10, 31, 127],
    
    
}
gbm = GridSearchCV(estimator=clf, param_grid=param_grid)
gbm.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=LGBMRegressor(boosting_type='gbdt', class_weight=None,
#                                      colsample_bytree=1.0,
#                                      importance_type='split', learning_rate=0.1,
#                                      max_depth=-1, min_child_samples=20,
#                                      min_child_weight=0.001, min_split_gain=0.0,
#                                      n_estimators=100, n_jobs=-1, num_leaves=31,
#                                      objective=None, random_state=None,
#                                      reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                                      subsample=1.0, subsample_for_bin=200000,
#                                      subsample_freq=0),
#              iid='deprecated', n_jobs=None,
#              param_grid={'boosting_type': ['gbdt', 'rf'],
#                          'learning rate': [0.1, 0.001, 0.003],
#                          'max_bin': [10, 100, 100],
#                          'num_leaves': [10, 31, 127]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
print('best parameters : ', gbm.best_params_)
print('best score : ', gbm.best_score_)
# Out:
# best parameters :  {'boosting_type': 'gbdt', 'learning rate': 0.1, 'max_bin': 10, 'num_leaves': 10}
# best score :  0.054162385346636824

# %%
LGBM=gbm.best_estimator_
predict = gbm.predict(X_test)  #0.78389

# %% [markdown]
# # 3. submission

# %%
predict
# Out:
# array([2.98269092, 2.7670509 , 2.84917391, ..., 2.04262467, 2.14783666,
#        2.18055248])

# %%
test['visitors'] = predict
test['visitors'] = np.expm1(test['visitors']).clip(lower=0.)
test
# Out:
#                     store_id  visit_date  ...  month expansion_after
# 252108  air_00a91d42b08b08d9  2017-04-23  ...      4               1
# 252109  air_00a91d42b08b08d9  2017-04-24  ...      4               1
# 252110  air_00a91d42b08b08d9  2017-04-25  ...      4               1
# 252111  air_00a91d42b08b08d9  2017-04-26  ...      4               1
# 252112  air_00a91d42b08b08d9  2017-04-27  ...      4               1
# ...                      ...         ...  ...    ...             ...
# 284122  air_fff68b929994bfbd  2017-05-27  ...      5               1
# 284123  air_fff68b929994bfbd  2017-05-28  ...      5               1
# 284124  air_fff68b929994bfbd  2017-05-29  ...      5               1
# 284125  air_fff68b929994bfbd  2017-05-30  ...      5               1
# 284126  air_fff68b929994bfbd  2017-05-31  ...      5               1
#
# [32019 rows x 15 columns]

# %%
sub = test[['id','visitors']].copy()
sub.to_csv('submission.csv', index=False)

# %%
import lightgbm as lgb
def lightgbm(data):
    train_size = len(air_visit)
    test = data[train_size:]

    restaurant = data.drop("latitude", axis=1).copy()
    restaurant.drop("longitude", axis=1, inplace=True)
    restaurant.drop("visit_date", axis=1, inplace=True)
    restaurant.drop("id", axis=1, inplace=True)
    restaurant.drop("store_id", axis=1, inplace=True)
    restaurant.drop("air_area_name", axis=1, inplace=True)
    restaurant.drop("air_area_name0", axis=1, inplace=True)

    train_data = restaurant[:train_size]
    test_data = restaurant[train_size:]

    y_train = train_data["visitors"].copy()
    X_train=train_data.drop("visitors", axis=1).copy() 

    X_test = test_data.drop("visitors", axis=1)
    
    lgb_train = lgb.Dataset(X_train, y_train)

    params = {}
    params['learning_rate'] = 0.003
    params['boosting_type'] = 'gbdt'
    params['objective'] = 'regression'
    params['metric'] = 'mse'
    params['sub_feature'] = 0.5
    params['num_leaves'] = 10
    params['min_data'] = 50
    params['max_depth'] = 10
    gbm = lgb.train(params,lgb_train,2300)
    predict = gbm.predict(X_test)  #0.78211
    test['visitors'] = predict
    test['visitors'] = np.expm1(test['visitors']).clip(lower=0.)
    sub = test[['id','visitors']].copy()
    sub.to_csv('submission.csv', index=False)

# %%
lightgbm(data)
